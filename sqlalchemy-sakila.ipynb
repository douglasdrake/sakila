# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine

# %%
# Connect to the sakila database
engine = create_engine('sqlite:///../sqlite-sakila.db')

# %%
# Declare a Base using `automap_base()`
Base = automap_base()

# %%
# Use the Base class to reflect the database tables
Base.prepare(engine, reflect=True)

# %%
# List the tables in the database
Base.classes.keys()
# Out:
# ['actor',
#  'address',
#  'city',
#  'country',
#  'category',
#  'customer',
#  'store',
#  'staff',
#  'film',
#  'language',
#  'film_actor',
#  'film_category',
#  'film_text',
#  'inventory',
#  'payment',
#  'rental']

# %%
# Assign the actor class to the variable Actor
Actor = Base.classes.actor

# %%
# Create a session
session = Session(engine)

# %%
# Look at the first row of the actor table
first_row = session.query(Actor).first()
first_row.__dict__
# Out:
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState at 0x173df0a8a20>,
#  'last_name': 'GUINESS',
#  'actor_id': 1,
#  'last_update': datetime.datetime(2019, 4, 11, 18, 11, 48),
#  'first_name': 'PENELOPE'}

# %%
# 1a. Display the first and last names of all actors from the table actor.
query = session.query(Actor)

for row in query:
    print(row.first_name, row.last_name)
# Out:
# PENELOPE GUINESS
# NICK WAHLBERG
# ED CHASE
# JENNIFER DAVIS
# JOHNNY LOLLOBRIGIDA
# BETTE NICHOLSON
# GRACE MOSTEL
# MATTHEW JOHANSSON
# JOE SWANK
# CHRISTIAN GABLE
# ZERO CAGE
# KARL BERRY
# UMA WOOD
# VIVIEN BERGEN
# CUBA OLIVIER
# FRED COSTNER
# HELEN VOIGHT
# DAN TORN
# BOB FAWCETT
# LUCILLE TRACY
# KIRSTEN PALTROW
# ELVIS MARX
# SANDRA KILMER
# CAMERON STREEP
# KEVIN BLOOM
# RIP CRAWFORD
# JULIA MCQUEEN
# WOODY HOFFMAN
# ALEC WAYNE
# SANDRA PECK
# SISSY SOBIESKI
# TIM HACKMAN
# MILLA PECK
# AUDREY OLIVIER
# JUDY DEAN
# BURT DUKAKIS
# VAL BOLGER
# TOM MCKELLEN
# GOLDIE BRODY
# JOHNNY CAGE
# JODIE DEGENERES
# TOM MIRANDA
# KIRK JOVOVICH
# NICK STALLONE
# REESE KILMER
# PARKER GOLDBERG
# JULIA BARRYMORE
# FRANCES DAY-LEWIS
# ANNE CRONYN
# NATALIE HOPKINS
# GARY PHOENIX
# CARMEN HUNT
# MENA TEMPLE
# PENELOPE PINKETT
# FAY KILMER
# DAN HARRIS
# JUDE CRUISE
# CHRISTIAN AKROYD
# DUSTIN TAUTOU
# HENRY BERRY
# CHRISTIAN NEESON
# JAYNE NEESON
# CAMERON WRAY
# RAY JOHANSSON
# ANGELA HUDSON
# MARY TANDY
# JESSICA BAILEY
# RIP WINSLET
# KENNETH PALTROW
# MICHELLE MCCONAUGHEY
# ADAM GRANT
# SEAN WILLIAMS
# GARY PENN
# MILLA KEITEL
# BURT POSEY
# ANGELINA ASTAIRE
# CARY MCCONAUGHEY
# GROUCHO SINATRA
# MAE HOFFMAN
# RALPH CRUZ
# SCARLETT DAMON
# WOODY JOLIE
# BEN WILLIS
# JAMES PITT
# MINNIE ZELLWEGER
# GREG CHAPLIN
# SPENCER PECK
# KENNETH PESCI
# CHARLIZE DENCH
# SEAN GUINESS
# CHRISTOPHER BERRY
# KIRSTEN AKROYD
# ELLEN PRESLEY
# KENNETH TORN
# DARYL WAHLBERG
# GENE WILLIS
# MEG HAWKE
# CHRIS BRIDGES
# JIM MOSTEL
# SPENCER DEPP
# SUSAN DAVIS
# WALTER TORN
# MATTHEW LEIGH
# PENELOPE CRONYN
# SIDNEY CROWE
# GROUCHO DUNST
# GINA DEGENERES
# WARREN NOLTE
# SYLVESTER DERN
# SUSAN DAVIS
# CAMERON ZELLWEGER
# RUSSELL BACALL
# MORGAN HOPKINS
# MORGAN MCDORMAND
# HARRISON BALE
# DAN STREEP
# RENEE TRACY
# CUBA ALLEN
# WARREN JACKMAN
# PENELOPE MONROE
# LIZA BERGMAN
# SALMA NOLTE
# JULIANNE DENCH
# SCARLETT BENING
# ALBERT NOLTE
# FRANCES TOMEI
# KEVIN GARLAND
# CATE MCQUEEN
# DARYL CRAWFORD
# GRETA KEITEL
# JANE JACKMAN
# ADAM HOPPER
# RICHARD PENN
# GENE HOPKINS
# RITA REYNOLDS
# ED MANSFIELD
# MORGAN WILLIAMS
# LUCILLE DEE
# EWAN GOODING
# WHOOPI HURT
# CATE HARRIS
# JADA RYDER
# RIVER DEAN
# ANGELA WITHERSPOON
# KIM ALLEN
# ALBERT JOHANSSON
# FAY WINSLET
# EMILY DEE
# RUSSELL TEMPLE
# JAYNE NOLTE
# GEOFFREY HESTON
# BEN HARRIS
# MINNIE KILMER
# MERYL GIBSON
# IAN TANDY
# FAY WOOD
# GRETA MALDEN
# VIVIEN BASINGER
# LAURA BRODY
# CHRIS DEPP
# HARVEY HOPE
# OPRAH KILMER
# CHRISTOPHER WEST
# HUMPHREY WILLIS
# AL GARLAND
# NICK DEGENERES
# LAURENCE BULLOCK
# WILL WILSON
# KENNETH HOFFMAN
# MENA HOPPER
# OLYMPIA PFEIFFER
# GROUCHO WILLIAMS
# ALAN DREYFUSS
# MICHAEL BENING
# WILLIAM HACKMAN
# JON CHASE
# GENE MCKELLEN
# LISA MONROE
# ED GUINESS
# JEFF SILVERSTONE
# MATTHEW CARREY
# DEBBIE AKROYD
# RUSSELL CLOSE
# HUMPHREY GARLAND
# MICHAEL BOLGER
# JULIA ZELLWEGER
# RENEE BALL
# ROCK DUKAKIS
# CUBA BIRCH
# AUDREY BAILEY
# GREGORY GOODING
# JOHN SUVARI
# BURT TEMPLE
# MERYL ALLEN
# JAYNE SILVERSTONE
# BELA WALKEN
# REESE WEST
# MARY KEITEL
# JULIA FAWCETT
# THORA TEMPLE

# %%
# 1b.  Display the first and last name of each actor in a single column in upper case letters. Name the column Actor Name
query = session.query(Actor.first_name, Actor.last_name).all()

#query
actor_name = [y +  ' ' + z for y, z in query]
actor_name
# Out:
# ['PENELOPE GUINESS',
#  'NICK WAHLBERG',
#  'ED CHASE',
#  'JENNIFER DAVIS',
#  'JOHNNY LOLLOBRIGIDA',
#  'BETTE NICHOLSON',
#  'GRACE MOSTEL',
#  'MATTHEW JOHANSSON',
#  'JOE SWANK',
#  'CHRISTIAN GABLE',
#  'ZERO CAGE',
#  'KARL BERRY',
#  'UMA WOOD',
#  'VIVIEN BERGEN',
#  'CUBA OLIVIER',
#  'FRED COSTNER',
#  'HELEN VOIGHT',
#  'DAN TORN',
#  'BOB FAWCETT',
#  'LUCILLE TRACY',
#  'KIRSTEN PALTROW',
#  'ELVIS MARX',
#  'SANDRA KILMER',
#  'CAMERON STREEP',
#  'KEVIN BLOOM',
#  'RIP CRAWFORD',
#  'JULIA MCQUEEN',
#  'WOODY HOFFMAN',
#  'ALEC WAYNE',
#  'SANDRA PECK',
#  'SISSY SOBIESKI',
#  'TIM HACKMAN',
#  'MILLA PECK',
#  'AUDREY OLIVIER',
#  'JUDY DEAN',
#  'BURT DUKAKIS',
#  'VAL BOLGER',
#  'TOM MCKELLEN',
#  'GOLDIE BRODY',
#  'JOHNNY CAGE',
#  'JODIE DEGENERES',
#  'TOM MIRANDA',
#  'KIRK JOVOVICH',
#  'NICK STALLONE',
#  'REESE KILMER',
#  'PARKER GOLDBERG',
#  'JULIA BARRYMORE',
#  'FRANCES DAY-LEWIS',
#  'ANNE CRONYN',
#  'NATALIE HOPKINS',
#  'GARY PHOENIX',
#  'CARMEN HUNT',
#  'MENA TEMPLE',
#  'PENELOPE PINKETT',
#  'FAY KILMER',
#  'DAN HARRIS',
#  'JUDE CRUISE',
#  'CHRISTIAN AKROYD',
#  'DUSTIN TAUTOU',
#  'HENRY BERRY',
#  'CHRISTIAN NEESON',
#  'JAYNE NEESON',
#  'CAMERON WRAY',
#  'RAY JOHANSSON',
#  'ANGELA HUDSON',
#  'MARY TANDY',
#  'JESSICA BAILEY',
#  'RIP WINSLET',
#  'KENNETH PALTROW',
#  'MICHELLE MCCONAUGHEY',
#  'ADAM GRANT',
#  'SEAN WILLIAMS',
#  'GARY PENN',
#  'MILLA KEITEL',
#  'BURT POSEY',
#  'ANGELINA ASTAIRE',
#  'CARY MCCONAUGHEY',
#  'GROUCHO SINATRA',
#  'MAE HOFFMAN',
#  'RALPH CRUZ',
#  'SCARLETT DAMON',
#  'WOODY JOLIE',
#  'BEN WILLIS',
#  'JAMES PITT',
#  'MINNIE ZELLWEGER',
#  'GREG CHAPLIN',
#  'SPENCER PECK',
#  'KENNETH PESCI',
#  'CHARLIZE DENCH',
#  'SEAN GUINESS',
#  'CHRISTOPHER BERRY',
#  'KIRSTEN AKROYD',
#  'ELLEN PRESLEY',
#  'KENNETH TORN',
#  'DARYL WAHLBERG',
#  'GENE WILLIS',
#  'MEG HAWKE',
#  'CHRIS BRIDGES',
#  'JIM MOSTEL',
#  'SPENCER DEPP',
#  'SUSAN DAVIS',
#  'WALTER TORN',
#  'MATTHEW LEIGH',
#  'PENELOPE CRONYN',
#  'SIDNEY CROWE',
#  'GROUCHO DUNST',
#  'GINA DEGENERES',
#  'WARREN NOLTE',
#  'SYLVESTER DERN',
#  'SUSAN DAVIS',
#  'CAMERON ZELLWEGER',
#  'RUSSELL BACALL',
#  'MORGAN HOPKINS',
#  'MORGAN MCDORMAND',
#  'HARRISON BALE',
#  'DAN STREEP',
#  'RENEE TRACY',
#  'CUBA ALLEN',
#  'WARREN JACKMAN',
#  'PENELOPE MONROE',
#  'LIZA BERGMAN',
#  'SALMA NOLTE',
#  'JULIANNE DENCH',
#  'SCARLETT BENING',
#  'ALBERT NOLTE',
#  'FRANCES TOMEI',
#  'KEVIN GARLAND',
#  'CATE MCQUEEN',
#  'DARYL CRAWFORD',
#  'GRETA KEITEL',
#  'JANE JACKMAN',
#  'ADAM HOPPER',
#  'RICHARD PENN',
#  'GENE HOPKINS',
#  'RITA REYNOLDS',
#  'ED MANSFIELD',
#  'MORGAN WILLIAMS',
#  'LUCILLE DEE',
#  'EWAN GOODING',
#  'WHOOPI HURT',
#  'CATE HARRIS',
#  'JADA RYDER',
#  'RIVER DEAN',
#  'ANGELA WITHERSPOON',
#  'KIM ALLEN',
#  'ALBERT JOHANSSON',
#  'FAY WINSLET',
#  'EMILY DEE',
#  'RUSSELL TEMPLE',
#  'JAYNE NOLTE',
#  'GEOFFREY HESTON',
#  'BEN HARRIS',
#  'MINNIE KILMER',
#  'MERYL GIBSON',
#  'IAN TANDY',
#  'FAY WOOD',
#  'GRETA MALDEN',
#  'VIVIEN BASINGER',
#  'LAURA BRODY',
#  'CHRIS DEPP',
#  'HARVEY HOPE',
#  'OPRAH KILMER',
#  'CHRISTOPHER WEST',
#  'HUMPHREY WILLIS',
#  'AL GARLAND',
#  'NICK DEGENERES',
#  'LAURENCE BULLOCK',
#  'WILL WILSON',
#  'KENNETH HOFFMAN',
#  'MENA HOPPER',
#  'OLYMPIA PFEIFFER',
#  'GROUCHO WILLIAMS',
#  'ALAN DREYFUSS',
#  'MICHAEL BENING',
#  'WILLIAM HACKMAN',
#  'JON CHASE',
#  'GENE MCKELLEN',
#  'LISA MONROE',
#  'ED GUINESS',
#  'JEFF SILVERSTONE',
#  'MATTHEW CARREY',
#  'DEBBIE AKROYD',
#  'RUSSELL CLOSE',
#  'HUMPHREY GARLAND',
#  'MICHAEL BOLGER',
#  'JULIA ZELLWEGER',
#  'RENEE BALL',
#  'ROCK DUKAKIS',
#  'CUBA BIRCH',
#  'AUDREY BAILEY',
#  'GREGORY GOODING',
#  'JOHN SUVARI',
#  'BURT TEMPLE',
#  'MERYL ALLEN',
#  'JAYNE SILVERSTONE',
#  'BELA WALKEN',
#  'REESE WEST',
#  'MARY KEITEL',
#  'JULIA FAWCETT',
#  'THORA TEMPLE']

# %%
# 2a. You need to find the ID number, first name, and last name of an actor, of whom you know only the first name, "Joe." What is one query would you use to obtain this information?

query = session.query(Actor.actor_id, Actor.first_name, Actor.last_name).filter(Actor.first_name == 'JOE').all()
query
# Out:
# [(9, 'JOE', 'SWANK')]

# %%
# 2b.
query = session.query(Actor.actor_id, Actor.first_name, Actor.last_name).filter(Actor.last_name.like("%GEN%"))
for row in query:
    print(row)
# Out:
# (14, 'VIVIEN', 'BERGEN')
# (41, 'JODIE', 'DEGENERES')
# (107, 'GINA', 'DEGENERES')
# (166, 'NICK', 'DEGENERES')

# %%
# 2c.
query = session.query(Actor.actor_id, Actor.first_name, Actor.last_name).filter(Actor.last_name.like("%LI%"))
for row in query:
    print(row)
# Out:
# (15, 'CUBA', 'OLIVIER')
# (34, 'AUDREY', 'OLIVIER')
# (72, 'SEAN', 'WILLIAMS')
# (82, 'WOODY', 'JOLIE')
# (83, 'BEN', 'WILLIS')
# (86, 'GREG', 'CHAPLIN')
# (96, 'GENE', 'WILLIS')
# (137, 'MORGAN', 'WILLIAMS')
# (164, 'HUMPHREY', 'WILLIS')
# (172, 'GROUCHO', 'WILLIAMS')

# %%
# 2d. 
Country = Base.classes.country

# %%
query = session.query(Country.country_id, Country.country).filter(Country.country.in_(['Afghanistan', 'Bangladesh', 'China'])).all()
for row in query:
    print(row)
# Out:
# (1, 'Afghanistan')
# (12, 'Bangladesh')
# (23, 'China')

# %%
# 4a. List the last names of actors, as well as how many actors have that last name.
from sqlalchemy import func

query = session.query(Actor.last_name, func.count(Actor.actor_id)).group_by(Actor.last_name)

for row in query:
    print(row)
# Out:
# ('AKROYD', 3)
# ('ALLEN', 3)
# ('ASTAIRE', 1)
# ('BACALL', 1)
# ('BAILEY', 2)
# ('BALE', 1)
# ('BALL', 1)
# ('BARRYMORE', 1)
# ('BASINGER', 1)
# ('BENING', 2)
# ('BERGEN', 1)
# ('BERGMAN', 1)
# ('BERRY', 3)
# ('BIRCH', 1)
# ('BLOOM', 1)
# ('BOLGER', 2)
# ('BRIDGES', 1)
# ('BRODY', 2)
# ('BULLOCK', 1)
# ('CAGE', 2)
# ('CARREY', 1)
# ('CHAPLIN', 1)
# ('CHASE', 2)
# ('CLOSE', 1)
# ('COSTNER', 1)
# ('CRAWFORD', 2)
# ('CRONYN', 2)
# ('CROWE', 1)
# ('CRUISE', 1)
# ('CRUZ', 1)
# ('DAMON', 1)
# ('DAVIS', 3)
# ('DAY-LEWIS', 1)
# ('DEAN', 2)
# ('DEE', 2)
# ('DEGENERES', 3)
# ('DENCH', 2)
# ('DEPP', 2)
# ('DERN', 1)
# ('DREYFUSS', 1)
# ('DUKAKIS', 2)
# ('DUNST', 1)
# ('FAWCETT', 2)
# ('GABLE', 1)
# ('GARLAND', 3)
# ('GIBSON', 1)
# ('GOLDBERG', 1)
# ('GOODING', 2)
# ('GRANT', 1)
# ('GUINESS', 3)
# ('HACKMAN', 2)
# ('HARRIS', 3)
# ('HAWKE', 1)
# ('HESTON', 1)
# ('HOFFMAN', 3)
# ('HOPE', 1)
# ('HOPKINS', 3)
# ('HOPPER', 2)
# ('HUDSON', 1)
# ('HUNT', 1)
# ('HURT', 1)
# ('JACKMAN', 2)
# ('JOHANSSON', 3)
# ('JOLIE', 1)
# ('JOVOVICH', 1)
# ('KEITEL', 3)
# ('KILMER', 5)
# ('LEIGH', 1)
# ('LOLLOBRIGIDA', 1)
# ('MALDEN', 1)
# ('MANSFIELD', 1)
# ('MARX', 1)
# ('MCCONAUGHEY', 2)
# ('MCDORMAND', 1)
# ('MCKELLEN', 2)
# ('MCQUEEN', 2)
# ('MIRANDA', 1)
# ('MONROE', 2)
# ('MOSTEL', 2)
# ('NEESON', 2)
# ('NICHOLSON', 1)
# ('NOLTE', 4)
# ('OLIVIER', 2)
# ('PALTROW', 2)
# ('PECK', 3)
# ('PENN', 2)
# ('PESCI', 1)
# ('PFEIFFER', 1)
# ('PHOENIX', 1)
# ('PINKETT', 1)
# ('PITT', 1)
# ('POSEY', 1)
# ('PRESLEY', 1)
# ('REYNOLDS', 1)
# ('RYDER', 1)
# ('SILVERSTONE', 2)
# ('SINATRA', 1)
# ('SOBIESKI', 1)
# ('STALLONE', 1)
# ('STREEP', 2)
# ('SUVARI', 1)
# ('SWANK', 1)
# ('TANDY', 2)
# ('TAUTOU', 1)
# ('TEMPLE', 4)
# ('TOMEI', 1)
# ('TORN', 3)
# ('TRACY', 2)
# ('VOIGHT', 1)
# ('WAHLBERG', 2)
# ('WALKEN', 1)
# ('WAYNE', 1)
# ('WEST', 2)
# ('WILLIAMS', 3)
# ('WILLIS', 3)
# ('WILSON', 1)
# ('WINSLET', 2)
# ('WITHERSPOON', 1)
# ('WOOD', 2)
# ('WRAY', 1)
# ('ZELLWEGER', 3)

# %%
# 4b. List last names of actors and the number of actors who have that last name, but only for names that are shared by at least two actors

query = session.query(Actor.last_name, func.count("*")).group_by(Actor.last_name).having(func.count("*") > 1).all()

for row in query:
    print(row)
# Out:
# ('AKROYD', 3)
# ('ALLEN', 3)
# ('BAILEY', 2)
# ('BENING', 2)
# ('BERRY', 3)
# ('BOLGER', 2)
# ('BRODY', 2)
# ('CAGE', 2)
# ('CHASE', 2)
# ('CRAWFORD', 2)
# ('CRONYN', 2)
# ('DAVIS', 3)
# ('DEAN', 2)
# ('DEE', 2)
# ('DEGENERES', 3)
# ('DENCH', 2)
# ('DEPP', 2)
# ('DUKAKIS', 2)
# ('FAWCETT', 2)
# ('GARLAND', 3)
# ('GOODING', 2)
# ('GUINESS', 3)
# ('HACKMAN', 2)
# ('HARRIS', 3)
# ('HOFFMAN', 3)
# ('HOPKINS', 3)
# ('HOPPER', 2)
# ('JACKMAN', 2)
# ('JOHANSSON', 3)
# ('KEITEL', 3)
# ('KILMER', 5)
# ('MCCONAUGHEY', 2)
# ('MCKELLEN', 2)
# ('MCQUEEN', 2)
# ('MONROE', 2)
# ('MOSTEL', 2)
# ('NEESON', 2)
# ('NOLTE', 4)
# ('OLIVIER', 2)
# ('PALTROW', 2)
# ('PECK', 3)
# ('PENN', 2)
# ('SILVERSTONE', 2)
# ('STREEP', 2)
# ('TANDY', 2)
# ('TEMPLE', 4)
# ('TORN', 3)
# ('TRACY', 2)
# ('WAHLBERG', 2)
# ('WEST', 2)
# ('WILLIAMS', 3)
# ('WILLIS', 3)
# ('WINSLET', 2)
# ('WOOD', 2)
# ('ZELLWEGER', 3)

# %%
# 6a. Use JOIN to display the first and last names, as well as the address, of each staff member. Use the tables staff and address:

Staff = Base.classes.staff
Address = Base.classes.address

# %%
query = session.query(Staff.first_name, Staff.last_name, Address.address).join(Address).all()
for row in query:
    print(row)
# Out:
# ('Mike', 'Hillyer', '23 Workhaven Lane')
# ('Jon', 'Stephens', '1411 Lillydale Drive')

# %%
# Look at the SQL statement
print(session.query(Staff.first_name, Staff.last_name, Address.address).join(Address))
# Out:
# SELECT staff.first_name AS staff_first_name, staff.last_name AS staff_last_name, address.address AS address_address
# FROM staff JOIN address ON address.address_id = staff.address_id

# %%
# 6b. Use JOIN to display the total amount rung up by each staff member in August of 2005. Use tables staff and payment.
Payment = Base.classes.payment

# %%
query = session.query(Staff.first_name, Staff.last_name, func.sum(Payment.amount)).join(Payment).group_by(Staff.staff_id).all()
for row in query:
    print(row)
# Out:
# ('Mike', 'Hillyer', Decimal('33489.47'))
# ('Jon', 'Stephens', Decimal('33927.04'))

# %%
# 6c. List each film and the number of actors who are listed for that film. Use tables film_actor and film. Use inner join
Film = Base.classes.film
Film_Actor = Base.classes.film_actor

# %%
query = session.query(Film.title, func.count("*")).join(Film_Actor).group_by(Film.title).all()
for row in query:
    print(row)
# Out:
# ('ACADEMY DINOSAUR', 10)
# ('ACE GOLDFINGER', 4)
# ('ADAPTATION HOLES', 5)
# ('AFFAIR PREJUDICE', 5)
# ('AFRICAN EGG', 5)
# ('AGENT TRUMAN', 7)
# ('AIRPLANE SIERRA', 5)
# ('AIRPORT POLLOCK', 4)
# ('ALABAMA DEVIL', 9)
# ('ALADDIN CALENDAR', 8)
# ('ALAMO VIDEOTAPE', 4)
# ('ALASKA PHANTOM', 7)
# ('ALI FOREVER', 5)
# ('ALICE FANTASIA', 4)
# ('ALIEN CENTER', 6)
# ('ALLEY EVOLUTION', 5)
# ('ALONE TRIP', 8)
# ('ALTER VICTORY', 4)
# ('AMADEUS HOLY', 6)
# ('AMELIE HELLFIGHTERS', 6)
# ('AMERICAN CIRCUS', 5)
# ('AMISTAD MIDSUMMER', 4)
# ('ANACONDA CONFESSIONS', 5)
# ('ANALYZE HOOSIERS', 5)
# ('ANGELS LIFE', 9)
# ('ANNIE IDENTITY', 3)
# ('ANONYMOUS HUMAN', 9)
# ('ANTHEM LUKE', 2)
# ('ANTITRUST TOMATOES', 7)
# ('ANYTHING SAVANNAH', 3)
# ('APACHE DIVINE', 4)
# ('APOCALYPSE FLAMINGOS', 5)
# ('APOLLO TEEN', 8)
# ('ARABIA DOGMA', 12)
# ('ARACHNOPHOBIA ROLLERCOASTER', 8)
# ('ARGONAUTS TOWN', 5)
# ('ARIZONA BANG', 4)
# ('ARK RIDGEMONT', 3)
# ('ARMAGEDDON LOST', 7)
# ('ARMY FLINTSTONES', 7)
# ('ARSENIC INDEPENDENCE', 3)
# ('ARTIST COLDBLOODED', 7)
# ('ATLANTIS CAUSE', 9)
# ('ATTACKS HATE', 4)
# ('ATTRACTION NEWTON', 4)
# ('AUTUMN CROW', 3)
# ('BABY HALL', 8)
# ('BACKLASH UNDEFEATED', 7)
# ('BADMAN DAWN', 8)
# ('BAKED CLEOPATRA', 1)
# ('BALLOON HOMEWARD', 6)
# ('BALLROOM MOCKINGBIRD', 7)
# ('BANG KWAI', 7)
# ('BANGER PINOCCHIO', 6)
# ('BARBARELLA STREETCAR', 5)
# ('BAREFOOT MANCHURIAN', 8)
# ('BASIC EASY', 6)
# ('BEACH HEARTBREAKERS', 7)
# ('BEAR GRACELAND', 3)
# ('BEAST HUNCHBACK', 5)
# ('BEAUTY GREASE', 5)
# ('BED HIGHBALL', 5)
# ('BEDAZZLED MARRIED', 7)
# ('BEETHOVEN EXORCIST', 6)
# ('BEHAVIOR RUNAWAY', 5)
# ('BENEATH RUSH', 7)
# ('BERETS AGENT', 10)
# ('BETRAYED REAR', 4)
# ('BEVERLY OUTLAW', 4)
# ('BIKINI BORROWERS', 2)
# ('BILKO ANONYMOUS', 3)
# ('BILL OTHERS', 6)
# ('BINGO TALENTED', 5)
# ('BIRCH ANTITRUST', 6)
# ('BIRD INDEPENDENCE', 2)
# ('BIRDCAGE CASPER', 4)
# ('BIRDS PERDITION', 4)
# ('BLACKOUT PRIVATE', 5)
# ('BLADE POLISH', 5)
# ('BLANKET BEVERLY', 4)
# ('BLINDNESS GUN', 3)
# ('BLOOD ARGONAUTS', 4)
# ('BLUES INSTINCT', 4)
# ('BOILED DARES', 8)
# ('BONNIE HOLOCAUST', 9)
# ('BOOGIE AMELIE', 6)
# ('BOONDOCK BALLROOM', 13)
# ('BORN SPINAL', 9)
# ('BORROWERS BEDAZZLED', 7)
# ('BOULEVARD MOB', 8)
# ('BOUND CHEAPER', 2)
# ('BOWFINGER GABLES', 5)
# ('BRANNIGAN SUNRISE', 2)
# ('BRAVEHEART HUMAN', 4)
# ('BREAKFAST GOLDFINGER', 5)
# ('BREAKING HOME', 6)
# ('BRIDE INTRIGUE', 1)
# ('BRIGHT ENCOUNTERS', 4)
# ('BRINGING HYSTERICAL', 2)
# ('BROOKLYN DESERT', 5)
# ('BROTHERHOOD BLANKET', 5)
# ('BUBBLE GROSSE', 3)
# ('BUCKET BROTHERHOOD', 6)
# ('BUGSY SONG', 2)
# ('BULL SHAWSHANK', 8)
# ('BULWORTH COMMANDMENTS', 4)
# ('BUNCH MINDS', 8)
# ('BUTCH PANTHER', 3)
# ('BUTTERFLY CHOCOLAT', 7)
# ('CABIN FLASH', 4)
# ('CADDYSHACK JEDI', 7)
# ('CALENDAR GUNFIGHT', 8)
# ('CALIFORNIA BIRDS', 2)
# ('CAMELOT VACATION', 2)
# ('CAMPUS REMEMBER', 3)
# ('CANDIDATE PERDITION', 4)
# ('CANDLES GRAPES', 7)
# ('CANYON STOCK', 6)
# ('CAPER MOTIONS', 7)
# ('CARIBBEAN LIBERTY', 8)
# ('CAROL TEXAS', 7)
# ('CARRIE BUNCH', 7)
# ('CASABLANCA SUPER', 4)
# ('CASPER DRAGONFLY', 5)
# ('CASSIDY WYOMING', 7)
# ('CASUALTIES ENCINO', 5)
# ('CAT CONEHEADS', 4)
# ('CATCH AMISTAD', 5)
# ('CAUSE DATE', 6)
# ('CELEBRITY HORN', 4)
# ('CENTER DINOSAUR', 4)
# ('CHAINSAW UPTOWN', 2)
# ('CHAMBER ITALIAN', 7)
# ('CHAMPION FLATLINERS', 4)
# ('CHANCE RESURRECTION', 6)
# ('CHAPLIN LICENSE', 6)
# ('CHARADE DUFFEL', 3)
# ('CHARIOTS CONSPIRACY', 2)
# ('CHASING FIGHT', 5)
# ('CHEAPER CLYDE', 2)
# ('CHICAGO NORTH', 8)
# ('CHICKEN HELLFIGHTERS', 2)
# ('CHILL LUCK', 5)
# ('CHINATOWN GLADIATOR', 10)
# ('CHISUM BEHAVIOR', 4)
# ('CHITTY LOCK', 13)
# ('CHOCOLAT HARRY', 5)
# ('CHOCOLATE DUCK', 7)
# ('CHRISTMAS MOONSHINE', 3)
# ('CIDER DESIRE', 5)
# ('CINCINATTI WHISPERER', 4)
# ('CIRCUS YOUTH', 2)
# ('CITIZEN SHREK', 8)
# ('CLASH FREDDY', 7)
# ('CLEOPATRA DEVIL', 7)
# ('CLERKS ANGELS', 4)
# ('CLOCKWORK PARADISE', 5)
# ('CLONES PINOCCHIO', 5)
# ('CLOSER BANG', 6)
# ('CLUB GRAFFITI', 4)
# ('CLUE GRAIL', 6)
# ('CLUELESS BUCKET', 8)
# ('CLYDE THEORY', 4)
# ('COAST RAINBOW', 10)
# ('COLDBLOODED DARLING', 4)
# ('COLOR PHILADELPHIA', 7)
# ('COMA HEAD', 3)
# ('COMANCHEROS ENEMY', 5)
# ('COMFORTS RUSH', 5)
# ('COMMAND DARLING', 8)
# ('COMMANDMENTS EXPRESS', 4)
# ('CONEHEADS SMOOCHY', 9)
# ('CONFESSIONS MAGUIRE', 4)
# ('CONFIDENTIAL INTERVIEW', 2)
# ('CONFUSED CANDLES', 6)
# ('CONGENIALITY QUEST', 3)
# ('CONNECTICUT TRAMP', 7)
# ('CONNECTION MICROCOSMOS', 7)
# ('CONQUERER NUTS', 6)
# ('CONSPIRACY SPIRIT', 4)
# ('CONTACT ANONYMOUS', 5)
# ('CONTROL ANTHEM', 3)
# ('CONVERSATION DOWNHILL', 3)
# ('CORE SUIT', 4)
# ('COWBOY DOOM', 5)
# ('CRAFT OUTFIELD', 6)
# ('CRANES RESERVOIR', 6)
# ('CRAZY HOME', 13)
# ('CREATURES SHAKESPEARE', 3)
# ('CREEPERS KANE', 6)
# ('CROOKED FROGMEN', 6)
# ('CROSSING DIVORCE', 2)
# ('CROSSROADS CASUALTIES', 8)
# ('CROW GREASE', 10)
# ('CROWDS TELEMARK', 4)
# ('CRUELTY UNFORGIVEN', 2)
# ('CRUSADE HONEY', 9)
# ('CRYSTAL BREAKING', 5)
# ('CUPBOARD SINNERS', 8)
# ('CURTAIN VIDEOTAPE', 3)
# ('CYCLONE FAMILY', 3)
# ('DADDY PITTSBURGH', 5)
# ('DAISY MENAGERIE', 7)
# ('DALMATIONS SWEDEN', 6)
# ('DANCES NONE', 5)
# ('DANCING FEVER', 6)
# ('DANGEROUS UPTOWN', 8)
# ('DARES PLUTO', 10)
# ('DARKNESS WAR', 2)
# ('DARKO DORADO', 4)
# ('DARLING BREAKING', 2)
# ('DARN FORRESTER', 9)
# ('DATE SPEED', 4)
# ('DAUGHTER MADIGAN', 4)
# ('DAWN POND', 6)
# ('DAY UNFAITHFUL', 5)
# ('DAZED PUNK', 6)
# ('DECEIVER BETRAYED', 4)
# ('DEEP CRUSADE', 7)
# ('DEER VIRGINIAN', 3)
# ('DELIVERANCE MULHOLLAND', 3)
# ('DESERT POSEIDON', 5)
# ('DESIRE ALIEN', 7)
# ('DESPERATE TRAINSPOTTING', 4)
# ('DESTINATION JERK', 3)
# ('DESTINY SATURDAY', 7)
# ('DETAILS PACKER', 2)
# ('DETECTIVE VISION', 3)
# ('DEVIL DESIRE', 5)
# ('DIARY PANIC', 4)
# ('DINOSAUR SECRETARY', 6)
# ('DIRTY ACE', 5)
# ('DISCIPLE MOTHER', 7)
# ('DISTURBING SCARFACE', 4)
# ('DIVIDE MONSTER', 6)
# ('DIVINE RESURRECTION', 5)
# ('DIVORCE SHINING', 6)
# ('DOCTOR GRAIL', 6)
# ('DOGMA FAMILY', 7)
# ('DOLLS RAGE', 1)
# ('DONNIE ALLEY', 7)
# ('DOOM DANCING', 8)
# ('DOORS PRESIDENT', 9)
# ('DORADO NOTTING', 4)
# ('DOUBLE WRATH', 8)
# ('DOUBTFIRE LABYRINTH', 5)
# ('DOWNHILL ENOUGH', 4)
# ('DOZEN LION', 6)
# ('DRACULA CRYSTAL', 13)
# ('DRAGON SQUAD', 8)
# ('DRAGONFLY STRANGERS', 3)
# ('DREAM PICKUP', 4)
# ('DRIFTER COMMANDMENTS', 7)
# ('DRIVER ANNIE', 8)
# ('DRIVING POLISH', 7)
# ('DROP WATERFRONT', 8)
# ('DRUMS DYNAMITE', 7)
# ('DUCK RACER', 2)
# ('DUDE BLINDNESS', 7)
# ('DUFFEL APOCALYPSE', 3)
# ('DUMBO LUST', 9)
# ('DURHAM PANKY', 9)
# ('DWARFS ALTER', 1)
# ('DYING MAKER', 2)
# ('DYNAMITE TARZAN', 5)
# ('EAGLES PANKY', 6)
# ('EARLY HOME', 6)
# ('EARRING INSTINCT', 5)
# ('EARTH VISION', 3)
# ('EASY GLADIATOR', 3)
# ('EDGE KISSING', 3)
# ('EFFECT GLADIATOR', 7)
# ('EGG IGBY', 5)
# ('EGYPT TENENBAUMS', 5)
# ('ELEMENT FREDDY', 4)
# ('ELEPHANT TROJAN', 5)
# ('ELF MURDER', 5)
# ('ELIZABETH SHANE', 3)
# ('EMPIRE MALKOVICH', 9)
# ('ENCINO ELF', 6)
# ('ENCOUNTERS CURTAIN', 4)
# ('ENDING CROWDS', 5)
# ('ENEMY ODDS', 4)
# ('ENGLISH BULWORTH', 5)
# ('ENOUGH RAGING', 9)
# ('ENTRAPMENT SATISFACTION', 4)
# ('ESCAPE METROPOLIS', 4)
# ('EVE RESURRECTION', 6)
# ('EVERYONE CRAFT', 5)
# ('EVOLUTION ALTER', 6)
# ('EXCITEMENT EVE', 8)
# ('EXORCIST STING', 5)
# ('EXPECATIONS NATURAL', 3)
# ('EXPENDABLE STALLION', 4)
# ('EXPRESS LONELY', 8)
# ('EXTRAORDINARY CONQUERER', 7)
# ('EYES DRIVING', 5)
# ('FACTORY DRAGON', 6)
# ('FALCON VOLUME', 4)
# ('FAMILY SWEET', 9)
# ('FANTASIA PARK', 3)
# ('FANTASY TROOPERS', 9)
# ('FARGO GANDHI', 5)
# ('FATAL HAUNTED', 6)
# ('FEATHERS METAL', 9)
# ('FELLOWSHIP AUTUMN', 7)
# ('FERRIS MOTHER', 1)
# ('FEUD FROGMEN', 4)
# ('FEVER EMPIRE', 3)
# ('FICTION CHRISTMAS', 8)
# ('FIDDLER LOST', 11)
# ('FIDELITY DEVIL', 4)
# ('FIGHT JAWBREAKER', 3)
# ('FINDING ANACONDA', 5)
# ('FIRE WOLVES', 5)
# ('FIREBALL PHILADELPHIA', 5)
# ('FIREHOUSE VIETNAM', 5)
# ('FISH OPUS', 2)
# ('FLAMINGOS CONNECTICUT', 9)
# ('FLASH WARS', 7)
# ('FLATLINERS KILLER', 9)
# ('FLINTSTONES HAPPINESS', 4)
# ('FLOATS GARDEN', 5)
# ('FLYING HOOK', 8)
# ('FOOL MOCKINGBIRD', 2)
# ('FOREVER CANDIDATE', 1)
# ('FORREST SONS', 5)
# ('FORRESTER COMANCHEROS', 3)
# ('FORWARD TEMPLE', 3)
# ('FRANKENSTEIN STRANGER', 2)
# ('FREAKY POCUS', 5)
# ('FREDDY STORM', 3)
# ('FREEDOM CLEOPATRA', 5)
# ('FRENCH HOLIDAY', 7)
# ('FRIDA SLIPPER', 5)
# ('FRISCO FORREST', 9)
# ('FROGMEN BREAKING', 6)
# ('FRONTIER CABIN', 6)
# ('FROST HEAD', 7)
# ('FUGITIVE MAGUIRE', 11)
# ('FULL FLATLINERS', 6)
# ('FURY MURDER', 4)
# ('GABLES METROPOLIS', 8)
# ('GALAXY SWEETHEARTS', 3)
# ('GAMES BOWFINGER', 8)
# ('GANDHI KWAI', 8)
# ('GANGS PRIDE', 4)
# ('GARDEN ISLAND', 3)
# ('GASLIGHT CRUSADE', 5)
# ('GATHERING CALENDAR', 3)
# ('GENTLEMEN STAGE', 8)
# ('GHOST GROUNDHOG', 5)
# ('GHOSTBUSTERS ELF', 1)
# ('GIANT TROOPERS', 1)
# ('GILBERT PELICAN', 4)
# ('GILMORE BOILED', 6)
# ('GLADIATOR WESTWARD', 6)
# ('GLASS DYING', 4)
# ('GLEAMING JAWBREAKER', 8)
# ('GLORY TRACY', 6)
# ('GO PURPLE', 3)
# ('GODFATHER DIARY', 6)
# ('GOLD RIVER', 2)
# ('GOLDFINGER SENSIBILITY', 4)
# ('GOLDMINE TYCOON', 7)
# ('GONE TROUBLE', 5)
# ('GOODFELLAS SALUTE', 8)
# ('GORGEOUS BINGO', 7)
# ('GOSFORD DONNIE', 3)
# ('GRACELAND DYNAMITE', 6)
# ('GRADUATE LORD', 2)
# ('GRAFFITI LOVE', 6)
# ('GRAIL FRANKENSTEIN', 5)
# ('GRAPES FURY', 5)
# ('GREASE YOUTH', 3)
# ('GREATEST NORTH', 6)
# ('GREEDY ROOTS', 8)
# ('GREEK EVERYONE', 4)
# ('GRINCH MASSAGE', 6)
# ('GRIT CLOCKWORK', 3)
# ('GROOVE FICTION', 7)
# ('GROSSE WONDERFUL', 4)
# ('GROUNDHOG UNCUT', 7)
# ('GUMP DATE', 6)
# ('GUN BONNIE', 5)
# ('GUNFIGHT MOON', 4)
# ('GUNFIGHTER MUSSOLINI', 4)
# ('GUYS FALCON', 5)
# ('HALF OUTFIELD', 6)
# ('HALL CASSIDY', 5)
# ('HALLOWEEN NUTS', 7)
# ('HAMLET WISDOM', 5)
# ('HANDICAP BOONDOCK', 7)
# ('HANGING DEEP', 7)
# ('HANKY OCTOBER', 3)
# ('HANOVER GALAXY', 7)
# ('HAPPINESS UNITED', 5)
# ('HARDLY ROBBERS', 3)
# ('HAROLD FRENCH', 7)
# ('HARPER DYING', 4)
# ('HARRY IDAHO', 6)
# ('HATE HANDICAP', 3)
# ('HAUNTED ANTITRUST', 5)
# ('HAUNTING PIANIST', 5)
# ('HAWK CHILL', 7)
# ('HEAD STRANGER', 2)
# ('HEARTBREAKERS BRIGHT', 5)
# ('HEAVEN FREEDOM', 10)
# ('HEAVENLY GUN', 6)
# ('HEAVYWEIGHTS BEAST', 5)
# ('HEDWIG ALTER', 4)
# ('HELLFIGHTERS SIERRA', 12)
# ('HIGH ENCINO', 7)
# ('HIGHBALL POTTER', 5)
# ('HILLS NEIGHBORS', 6)
# ('HOBBIT ALIEN', 8)
# ('HOCUS FRIDA', 3)
# ('HOLES BRANNIGAN', 11)
# ('HOLIDAY GAMES', 6)
# ('HOLLOW JEOPARDY', 2)
# ('HOLLYWOOD ANONYMOUS', 6)
# ('HOLOCAUST HIGHBALL', 5)
# ('HOLY TADPOLE', 3)
# ('HOME PITY', 6)
# ('HOMEWARD CIDER', 7)
# ('HOMICIDE PEACH', 8)
# ('HONEY TIES', 5)
# ('HOOK CHARIOTS', 4)
# ('HOOSIERS BIRDCAGE', 10)
# ('HOPE TOOTSIE', 4)
# ('HORN WORKING', 8)
# ('HORROR REIGN', 5)
# ('HOTEL HAPPINESS', 4)
# ('HOURS RAGE', 6)
# ('HOUSE DYNAMITE', 9)
# ('HUMAN GRAFFITI', 4)
# ('HUNCHBACK IMPOSSIBLE', 2)
# ('HUNGER ROOF', 1)
# ('HUNTER ALTER', 4)
# ('HUNTING MUSKETEERS', 5)
# ('HURRICANE AFFAIR', 3)
# ('HUSTLER PARTY', 4)
# ('HYDE DOCTOR', 6)
# ('HYSTERICAL GRAIL', 9)
# ('ICE CROSSING', 6)
# ('IDAHO LOVE', 6)
# ('IDENTITY LOVER', 4)
# ('IDOLS SNATCHERS', 8)
# ('IGBY MAKER', 5)
# ('ILLUSION AMELIE', 7)
# ('IMAGE PRINCESS', 11)
# ('IMPACT ALADDIN', 3)
# ('IMPOSSIBLE PREJUDICE', 3)
# ('INCH JET', 5)
# ('INDEPENDENCE HOTEL', 9)
# ('INDIAN LOVE', 10)
# ('INFORMER DOUBLE', 3)
# ('INNOCENT USUAL', 3)
# ('INSECTS STONE', 4)
# ('INSIDER ARIZONA', 9)
# ('INSTINCT AIRPORT', 11)
# ('INTENTIONS EMPIRE', 2)
# ('INTERVIEW LIAISONS', 5)
# ('INTOLERABLE INTENTIONS', 6)
# ('INTRIGUE WORST', 7)
# ('INVASION CYCLONE', 7)
# ('IRON MOON', 8)
# ('ISHTAR ROCKETEER', 4)
# ('ISLAND EXORCIST', 3)
# ('ITALIAN AFRICAN', 2)
# ('JACKET FRISCO', 10)
# ('JADE BUNCH', 8)
# ('JAPANESE RUN', 9)
# ('JASON TRAP', 5)
# ('JAWBREAKER BROOKLYN', 5)
# ('JAWS HARRY', 5)
# ('JEDI BENEATH', 4)
# ('JEEPERS WEDDING', 6)
# ('JEKYLL FROGMEN', 3)
# ('JEOPARDY ENCINO', 5)
# ('JERICHO MULAN', 4)
# ('JERK PAYCHECK', 8)
# ('JERSEY SASSY', 9)
# ('JET NEIGHBORS', 6)
# ('JINGLE SAGEBRUSH', 2)
# ('JOON NORTHWEST', 2)
# ('JUGGLER HARDLY', 9)
# ('JUMANJI BLADE', 6)
# ('JUMPING WRATH', 8)
# ('JUNGLE CLOSER', 6)
# ('KANE EXORCIST', 5)
# ('KARATE MOON', 8)
# ('KENTUCKIAN GIANT', 4)
# ('KICK SAVANNAH', 6)
# ('KILL BROTHERHOOD', 5)
# ('KILLER INNOCENT', 5)
# ('KING EVOLUTION', 6)
# ('KISS GLORY', 7)
# ('KISSING DOLLS', 3)
# ('KNOCK WARLOCK', 6)
# ('KRAMER CHOCOLATE', 8)
# ('KWAI HOMEWARD', 5)
# ('LABYRINTH LEAGUE', 6)
# ('LADY STAGE', 8)
# ('LADYBUGS ARMAGEDDON', 4)
# ('LAMBS CINCINATTI', 15)
# ('LANGUAGE COWBOY', 6)
# ('LAWLESS VISION', 4)
# ('LAWRENCE LOVE', 2)
# ('LEAGUE HELLFIGHTERS', 6)
# ('LEATHERNECKS DWARFS', 7)
# ('LEBOWSKI SOLDIERS', 3)
# ('LEGALLY SECRETARY', 6)
# ('LEGEND JEDI', 4)
# ('LESSON CLEOPATRA', 12)
# ('LIAISONS SWEET', 6)
# ('LIBERTY MAGNIFICENT', 7)
# ('LICENSE WEEKEND', 8)
# ('LIES TREATMENT', 7)
# ('LIFE TWISTED', 8)
# ('LIGHTS DEER', 2)
# ('LION UNCUT', 3)
# ('LOATHING LEGALLY', 5)
# ('LOCK REAR', 2)
# ('LOLA AGENT', 6)
# ('LOLITA WORLD', 1)
# ('LONELY ELEPHANT', 12)
# ('LORD ARIZONA', 6)
# ('LOSE INCH', 4)
# ('LOSER HUSTLER', 5)
# ('LOST BIRD', 3)
# ('LOUISIANA HARRY', 3)
# ('LOVE SUICIDES', 4)
# ('LOVELY JINGLE', 6)
# ('LOVER TRUMAN', 7)
# ('LOVERBOY ATTACKS', 9)
# ('LUCK OPUS', 6)
# ('LUCKY FLYING', 10)
# ('LUKE MUMMY', 9)
# ('LUST LOCK', 7)
# ('MADIGAN DORADO', 6)
# ('MADISON TRAP', 5)
# ('MADNESS ATTACKS', 7)
# ('MADRE GABLES', 4)
# ('MAGIC MALLRATS', 4)
# ('MAGNIFICENT CHITTY', 7)
# ('MAGNOLIA FORRESTER', 7)
# ('MAGUIRE APACHE', 4)
# ('MAIDEN HOME', 8)
# ('MAJESTIC FLOATS', 5)
# ('MAKER GABLES', 11)
# ('MALKOVICH PET', 7)
# ('MALLRATS UNITED', 5)
# ('MALTESE HOPE', 1)
# ('MANCHURIAN CURTAIN', 2)
# ('MANNEQUIN WORST', 5)
# ('MARRIED GO', 3)
# ('MARS ROMAN', 7)
# ('MASK PEACH', 11)
# ('MASKED BUBBLE', 3)
# ('MASSACRE USUAL', 3)
# ('MASSAGE IMAGE', 9)
# ('MATRIX SNOWMAN', 3)
# ('MAUDE MOD', 6)
# ('MEET CHOCOLATE', 6)
# ('MEMENTO ZOOLANDER', 6)
# ('MENAGERIE RUSHMORE', 2)
# ('MERMAID INSECTS', 6)
# ('METAL ARMAGEDDON', 8)
# ('METROPOLIS COMA', 6)
# ('MICROCOSMOS PARADISE', 6)
# ('MIDNIGHT WESTWARD', 9)
# ('MIDSUMMER GROUNDHOG', 2)
# ('MIGHTY LUCK', 8)
# ('MILE MULAN', 3)
# ('MILLION ACE', 5)
# ('MINDS TRUMAN', 6)
# ('MINE TITANS', 2)
# ('MINORITY KISS', 1)
# ('MIRACLE VIRTUAL', 1)
# ('MISSION ZOOLANDER', 5)
# ('MIXED DOORS', 6)
# ('MOB DUFFEL', 6)
# ('MOCKINGBIRD HOLLYWOOD', 3)
# ('MOD SECRETARY', 6)
# ('MODEL FISH', 8)
# ('MODERN DORADO', 5)
# ('MONEY HAROLD', 7)
# ('MONSOON CAUSE', 5)
# ('MONSTER SPARTACUS', 7)
# ('MONTEREY LABYRINTH', 6)
# ('MONTEZUMA COMMAND', 2)
# ('MOON BUNCH', 1)
# ('MOONSHINE CABIN', 5)
# ('MOONWALKER FOOL', 7)
# ('MOSQUITO ARMAGEDDON', 4)
# ('MOTHER OLEANDER', 5)
# ('MOTIONS DETAILS', 8)
# ('MOULIN WAKE', 3)
# ('MOURNING PURPLE', 7)
# ('MOVIE SHAKESPEARE', 8)
# ('MULAN MOON', 5)
# ('MULHOLLAND BEAST', 6)
# ('MUMMY CREATURES', 13)
# ('MUPPET MILE', 8)
# ('MURDER ANTITRUST', 8)
# ('MUSCLE BRIGHT', 5)
# ('MUSIC BOONDOCK', 3)
# ('MUSKETEERS WAIT', 1)
# ('MUSSOLINI SPOILERS', 7)
# ('MYSTIC TRUMAN', 4)
# ('NAME DETECTIVE', 3)
# ('NASH CHOCOLAT', 7)
# ('NATIONAL STORY', 7)
# ('NATURAL STOCK', 4)
# ('NECKLACE OUTBREAK', 8)
# ('NEIGHBORS CHARADE', 7)
# ('NEMO CAMPUS', 5)
# ('NETWORK PEAK', 3)
# ('NEWSIES STORY', 8)
# ('NEWTON LABYRINTH', 4)
# ('NIGHTMARE CHILL', 2)
# ('NONE SPIKING', 6)
# ('NOON PAPI', 6)
# ('NORTH TEQUILA', 5)
# ('NORTHWEST POLISH', 8)
# ('NOTORIOUS REUNION', 2)
# ('NOTTING SPEAKEASY', 2)
# ('NOVOCAINE FLIGHT', 6)
# ('NUTS TIES', 2)
# ('OCTOBER SUBMARINE', 5)
# ('ODDS BOOGIE', 5)
# ('OKLAHOMA JUMANJI', 9)
# ('OLEANDER CLUE', 10)
# ('OPEN AFRICAN', 9)
# ('OPERATION OPERATION', 3)
# ('OPPOSITE NECKLACE', 6)
# ('OPUS ICE', 4)
# ('ORANGE GRAPES', 5)
# ('ORDER BETRAYED', 7)
# ('ORIENT CLOSER', 4)
# ('OSCAR GOLD', 6)
# ('OTHERS SOUP', 4)
# ('OUTBREAK DIVINE', 5)
# ('OUTFIELD MASSACRE', 4)
# ('OUTLAW HANKY', 7)
# ('OZ LIAISONS', 11)
# ('PACIFIC AMISTAD', 8)
# ('PACKER MADIGAN', 1)
# ('PAJAMA JAWBREAKER', 5)
# ('PANIC CLUB', 3)
# ('PANKY SUBMARINE', 8)
# ('PANTHER REDS', 5)
# ('PAPI NECKLACE', 3)
# ('PARADISE SABRINA', 4)
# ('PARIS WEEKEND', 6)
# ('PARK CITIZEN', 6)
# ('PARTY KNOCK', 2)
# ('PAST SUICIDES', 6)
# ('PATHS CONTROL', 5)
# ('PATIENT SISTER', 4)
# ('PATRIOT ROMAN', 4)
# ('PATTON INTERVIEW', 9)
# ('PAYCHECK WAIT', 3)
# ('PEACH INNOCENT', 5)
# ('PEAK FOREVER', 5)
# ('PEARL DESTINY', 4)
# ('PELICAN COMFORTS', 5)
# ('PERDITION FARGO', 5)
# ('PERFECT GROOVE', 6)
# ('PERSONAL LADYBUGS', 9)
# ('PET HAUNTING', 7)
# ('PHANTOM GLORY', 2)
# ('PHILADELPHIA WIFE', 2)
# ('PIANIST OUTFIELD', 5)
# ('PICKUP DRIVING', 5)
# ('PILOT HOOSIERS', 7)
# ('PINOCCHIO SIMON', 11)
# ('PIRATES ROXANNE', 1)
# ('PITTSBURGH HUNCHBACK', 5)
# ('PITY BOUND', 5)
# ('PIZZA JUMANJI', 5)
# ('PLATOON INSTINCT', 5)
# ('PLUTO OLEANDER', 7)
# ('POCUS PULP', 5)
# ('POLISH BROOKLYN', 10)
# ('POLLOCK DELIVERANCE', 6)
# ('POND SEATTLE', 3)
# ('POSEIDON FOREVER', 6)
# ('POTLUCK MIXED', 6)
# ('POTTER CONNECTICUT', 7)
# ('PREJUDICE OLEANDER', 10)
# ('PRESIDENT BANG', 5)
# ('PRIDE ALAMO', 4)
# ('PRIMARY GLASS', 7)
# ('PRINCESS GIANT', 5)
# ('PRIVATE DROP', 5)
# ('PRIX UNDEFEATED', 7)
# ('PSYCHO SHRUNK', 1)
# ('PULP BEVERLY', 7)
# ('PUNK DIVORCE', 7)
# ('PURE RUNNER', 2)
# ('PURPLE MOVIE', 8)
# ('QUEEN LUKE', 6)
# ('QUEST MUSSOLINI', 5)
# ('QUILLS BULL', 4)
# ('RACER EGG', 6)
# ('RAGE GAMES', 7)
# ('RAGING AIRPLANE', 3)
# ('RAIDERS ANTITRUST', 6)
# ('RAINBOW SHOCK', 6)
# ('RANDOM GO', 13)
# ('RANGE MOONWALKER', 4)
# ('REAP UNFAITHFUL', 4)
# ('REAR TRADING', 8)
# ('REBEL AIRPORT', 6)
# ('RECORDS ZORRO', 8)
# ('REDEMPTION COMFORTS', 5)
# ('REDS POCUS', 5)
# ('REEF SALUTE', 4)
# ('REIGN GENTLEMEN', 3)
# ('REMEMBER DIARY', 4)
# ('REQUIEM TYCOON', 8)
# ('RESERVOIR ADAPTATION', 8)
# ('RESURRECTION SILVERADO', 5)
# ('REUNION WITCHES', 7)
# ('RIDER CADDYSHACK', 9)
# ('RIDGEMONT SUBMARINE', 5)
# ('RIGHT CRANES', 7)
# ('RINGS HEARTBREAKERS', 11)
# ('RIVER OUTLAW', 4)
# ('ROAD ROXANNE', 8)
# ('ROBBERS JOON', 5)
# ('ROBBERY BRIGHT', 2)
# ('ROCK INSTINCT', 8)
# ('ROCKETEER MOTHER', 7)
# ('ROCKY WAR', 3)
# ('ROLLERCOASTER BRINGING', 3)
# ('ROMAN PUNK', 2)
# ('ROOF CHAMPION', 5)
# ('ROOM ROMAN', 2)
# ('ROOTS REMEMBER', 10)
# ('ROSES TREASURE', 5)
# ('ROUGE SQUAD', 4)
# ('ROXANNE REBEL', 5)
# ('RUGRATS SHAKESPEARE', 6)
# ('RULES HUMAN', 5)
# ('RUN PACIFIC', 6)
# ('RUNAWAY TENENBAUMS', 3)
# ('RUNNER MADIGAN', 8)
# ('RUSH GOODFELLAS', 5)
# ('RUSHMORE MERMAID', 7)
# ('SABRINA MIDNIGHT', 4)
# ('SADDLE ANTITRUST', 3)
# ('SAGEBRUSH CLUELESS', 7)
# ('SAINTS BRIDE', 10)
# ('SALUTE APOLLO', 4)
# ('SAMURAI LION', 2)
# ('SANTA PARIS', 6)
# ('SASSY PACKER', 3)
# ('SATISFACTION CONFIDENTIAL', 5)
# ('SATURDAY LAMBS', 9)
# ('SATURN NAME', 2)
# ('SAVANNAH TOWN', 6)
# ('SCALAWAG DUCK', 5)
# ('SCARFACE BANG', 7)
# ('SCHOOL JACKET', 8)
# ('SCISSORHANDS SLUMS', 5)
# ('SCORPION APOLLO', 8)
# ('SEA VIRGIN', 8)
# ('SEABISCUIT PUNK', 3)
# ('SEARCHERS WAIT', 4)
# ('SEATTLE EXPECATIONS', 6)
# ('SECRET GROUNDHOG', 3)
# ('SECRETARY ROUGE', 6)
# ('SECRETS PARADISE', 6)
# ('SENSE GREEK', 7)
# ('SENSIBILITY REAR', 6)
# ('SEVEN SWARM', 7)
# ('SHAKESPEARE SADDLE', 6)
# ('SHANE DARKNESS', 3)
# ('SHANGHAI TYCOON', 8)
# ('SHAWSHANK BUBBLE', 10)
# ('SHEPHERD MIDSUMMER', 5)
# ('SHINING ROSES', 5)
# ('SHIP WONDERLAND', 8)
# ('SHOCK CABIN', 1)
# ('SHOOTIST SUPERFLY', 3)
# ('SHOW LORD', 2)
# ('SHREK LICENSE', 3)
# ('SHRUNK DIVINE', 4)
# ('SIDE ARK', 6)
# ('SIEGE MADRE', 7)
# ('SIERRA DIVIDE', 5)
# ('SILENCE KANE', 4)
# ('SILVERADO GOLDFINGER', 5)
# ('SIMON NORTH', 3)
# ('SINNERS ATLANTIS', 4)
# ('SISTER FREDDY', 3)
# ('SKY MIRACLE', 12)
# ('SLEEPING SUSPECTS', 4)
# ('SLEEPLESS MONSOON', 4)
# ('SLEEPY JAPANESE', 6)
# ('SLEUTH ORIENT', 7)
# ('SLING LUKE', 3)
# ('SLIPPER FIDELITY', 7)
# ('SLUMS DUCK', 3)
# ('SMILE EARRING', 8)
# ('SMOKING BARBARELLA', 6)
# ('SMOOCHY CONTROL', 2)
# ('SNATCH SLIPPER', 3)
# ('SNATCHERS MONTEZUMA', 9)
# ('SNOWMAN ROLLERCOASTER', 3)
# ('SOLDIERS EVOLUTION', 9)
# ('SOMETHING DUCK', 3)
# ('SONG HEDWIG', 5)
# ('SONS INTERVIEW', 6)
# ('SORORITY QUEEN', 4)
# ('SOUP WISDOM', 2)
# ('SOUTH WAIT', 2)
# ('SPARTACUS CHEAPER', 3)
# ('SPEAKEASY DATE', 3)
# ('SPEED SUIT', 6)
# ('SPICE SORORITY', 11)
# ('SPIKING ELEMENT', 6)
# ('SPINAL ROCKY', 8)
# ('SPIRIT FLINTSTONES', 11)
# ('SPIRITED CASUALTIES', 5)
# ('SPLASH GUMP', 10)
# ('SPLENDOR PATTON', 10)
# ('SPOILERS HELLFIGHTERS', 7)
# ('SPY MILE', 8)
# ('SQUAD FISH', 5)
# ('STAGE WORLD', 2)
# ('STAGECOACH ARMAGEDDON', 6)
# ('STALLION SUNDANCE', 7)
# ('STAMPEDE DISTURBING', 6)
# ('STAR OPERATION', 5)
# ('STATE WASTELAND', 7)
# ('STEEL SANTA', 3)
# ('STEERS ARMAGEDDON', 4)
# ('STEPMOM DREAM', 4)
# ('STING PERSONAL', 7)
# ('STOCK GLASS', 7)
# ('STONE FIRE', 1)
# ('STORM HAPPINESS', 8)
# ('STORY SIDE', 5)
# ('STRAIGHT HOURS', 3)
# ('STRANGELOVE DESIRE', 9)
# ('STRANGER STRANGERS', 9)
# ('STRANGERS GRAFFITI', 5)
# ('STREAK RIDGEMONT', 3)
# ('STREETCAR INTENTIONS', 7)
# ('STRICTLY SCARFACE', 4)
# ('SUBMARINE BED', 11)
# ('SUGAR WONKA', 5)
# ('SUICIDES SILENCE', 3)
# ('SUIT WALLS', 5)
# ('SUMMER SCARFACE', 8)
# ('SUN CONFESSIONS', 5)
# ('SUNDANCE INVASION', 7)
# ('SUNRISE LEAGUE', 5)
# ('SUNSET RACER', 3)
# ('SUPER WYOMING', 3)
# ('SUPERFLY TRIP', 7)
# ('SUSPECTS QUILLS', 8)
# ('SWARM GOLD', 6)
# ('SWEDEN SHINING', 5)
# ('SWEET BROTHERHOOD', 6)
# ('SWEETHEARTS SUSPECTS', 5)
# ('TADPOLE PARK', 8)
# ('TALENTED HOMICIDE', 5)
# ('TARZAN VIDEOTAPE', 3)
# ('TAXI KICK', 6)
# ('TEEN APOLLO', 5)
# ('TELEGRAPH VOYAGE', 7)
# ('TELEMARK HEARTBREAKERS', 11)
# ('TEMPLE ATTRACTION', 5)
# ('TENENBAUMS COMMAND', 5)
# ('TEQUILA PAST', 3)
# ('TERMINATOR CLUB', 2)
# ('TEXAS WATCH', 6)
# ('THEORY MERMAID', 6)
# ('THIEF PELICAN', 7)
# ('THIN SAGEBRUSH', 2)
# ('TIES HUNGER', 6)
# ('TIGHTS DAWN', 5)
# ('TIMBERLAND SKY', 4)
# ('TITANIC BOONDOCK', 12)
# ('TITANS JERK', 7)
# ('TOMATOES HELLFIGHTERS', 9)
# ('TOMORROW HUSTLER', 6)
# ('TOOTSIE PILOT', 5)
# ('TORQUE BOUND', 5)
# ('TOURIST PELICAN', 3)
# ('TOWERS HURRICANE', 4)
# ('TOWN ARK', 4)
# ('TRACY CIDER', 3)
# ('TRADING PINOCCHIO', 3)
# ('TRAFFIC HOBBIT', 4)
# ('TRAIN BUNCH', 4)
# ('TRAINSPOTTING STRANGERS', 4)
# ('TRAMP OTHERS', 6)
# ('TRANSLATION SUMMER', 3)
# ('TRAP GUYS', 7)
# ('TREASURE COMMAND', 7)
# ('TREATMENT JEKYLL', 5)
# ('TRIP NEWTON', 4)
# ('TROJAN TOMORROW', 8)
# ('TROOPERS METAL', 5)
# ('TROUBLE DATE', 8)
# ('TRUMAN CRAZY', 6)
# ('TURN STAR', 3)
# ('TUXEDO MILE', 3)
# ('TWISTED PIRATES', 3)
# ('TYCOON GATHERING', 6)
# ('UNBREAKABLE KARATE', 8)
# ('UNCUT SUICIDES', 7)
# ('UNDEFEATED DALMATIONS', 3)
# ('UNFAITHFUL KILL', 8)
# ('UNFORGIVEN ZOOLANDER', 7)
# ('UNITED PILOT', 6)
# ('UNTOUCHABLES SUNRISE', 5)
# ('UPRISING UPTOWN', 5)
# ('UPTOWN YOUNG', 7)
# ('USUAL UNTOUCHABLES', 5)
# ('VACATION BOONDOCK', 6)
# ('VALENTINE VANISHING', 2)
# ('VALLEY PACKER', 4)
# ('VAMPIRE WHALE', 5)
# ('VANILLA DAY', 2)
# ('VANISHED GARDEN', 2)
# ('VANISHING ROCKY', 5)
# ('VARSITY TRIP', 3)
# ('VELVET TERMINATOR', 9)
# ('VERTIGO NORTHWEST', 4)
# ('VICTORY ACADEMY', 5)
# ('VIDEOTAPE ARSENIC', 5)
# ('VIETNAM SMOOCHY', 2)
# ('VILLAIN DESPERATE', 2)
# ('VIRGIN DAISY', 8)
# ('VIRGINIAN PLUTO', 8)
# ('VIRTUAL SPOILERS', 3)
# ('VISION TORQUE', 5)
# ('VOICE PEACH', 3)
# ('VOLCANO TEXAS', 5)
# ('VOLUME HOUSE', 5)
# ('VOYAGE LEGALLY', 5)
# ('WAGON JAWS', 6)
# ('WAIT CIDER', 9)
# ('WAKE JAWS', 5)
# ('WALLS ARTIST', 5)
# ('WANDA CHAMBER', 7)
# ('WAR NOTTING', 9)
# ('WARDROBE PHANTOM', 8)
# ('WARLOCK WEREWOLF', 6)
# ('WARS PLUTO', 4)
# ('WASH HEAVENLY', 5)
# ('WASTELAND DIVINE', 6)
# ('WATCH TRACY', 5)
# ('WATERFRONT DELIVERANCE', 6)
# ('WATERSHIP FRONTIER', 6)
# ('WEDDING APOLLO', 10)
# ('WEEKEND PERSONAL', 10)
# ('WEREWOLF LOLA', 7)
# ('WEST LION', 9)
# ('WESTWARD SEABISCUIT', 6)
# ('WHALE BIKINI', 5)
# ('WHISPERER GIANT', 3)
# ('WIFE TURN', 6)
# ('WILD APOLLO', 4)
# ('WILLOW TRACY', 2)
# ('WIND PHANTOM', 3)
# ('WINDOW SIDE', 4)
# ('WISDOM WORKER', 7)
# ('WITCHES PANIC', 4)
# ('WIZARD COLDBLOODED', 9)
# ('WOLVES DESIRE', 6)
# ('WOMEN DORADO', 5)
# ('WON DARES', 5)
# ('WONDERFUL DROP', 4)
# ('WONDERLAND CHRISTMAS', 5)
# ('WONKA SEA', 2)
# ('WORDS HUNTER', 6)
# ('WORKER TARZAN', 9)
# ('WORKING MICROCOSMOS', 5)
# ('WORLD LEATHERNECKS', 8)
# ('WORST BANGER', 4)
# ('WRATH MILE', 4)
# ('WRONG BEHAVIOR', 9)
# ('WYOMING STORM', 6)
# ('YENTL IDAHO', 1)
# ('YOUNG LANGUAGE', 5)
# ('YOUTH KICK', 5)
# ('ZHIVAGO CORE', 6)
# ('ZOOLANDER FICTION', 5)
# ('ZORRO ARK', 3)

# %%
# 6d. How many copies of the film Hunchback Impossible exist in the inventory system?
Inventory = Base.classes.inventory

session.query(func.count(Inventory.inventory_id)).join(Film).filter(
    Film.title == 'HUNCHBACK IMPOSSIBLE'    
).group_by(Film.film_id).scalar()
# Out:
# 6

# %%
# 6e. Using the tables payment and customer and the JOIN command, list the total paid by each customer. List the customers alphabetically by last name

Customer = Base.classes.customer

query = session.query(Customer.first_name, Customer.last_name, func.sum(Payment.amount)).join(Payment).group_by(Customer.customer_id).order_by(Customer.last_name, Customer.first_name)

for row in query:
    print(row)
# Out:
# ('RAFAEL', 'ABNEY', Decimal('97.79'))
# ('NATHANIEL', 'ADAM', Decimal('133.72'))
# ('KATHLEEN', 'ADAMS', Decimal('92.73'))
# ('DIANA', 'ALEXANDER', Decimal('105.73'))
# ('GORDON', 'ALLARD', Decimal('160.68'))
# ('SHIRLEY', 'ALLEN', Decimal('126.69'))
# ('CHARLENE', 'ALVAREZ', Decimal('114.73'))
# ('LISA', 'ANDERSON', Decimal('106.76'))
# ('JOSE', 'ANDREW', Decimal('96.75'))
# ('IDA', 'ANDREWS', Decimal('76.77'))
# ('OSCAR', 'AQUINO', Decimal('99.80'))
# ('HARRY', 'ARCE', Decimal('157.65'))
# ('JORDAN', 'ARCHULETA', Decimal('132.70'))
# ('MELANIE', 'ARMSTRONG', Decimal('92.75'))
# ('BEATRICE', 'ARNOLD', Decimal('119.74'))
# ('KENT', 'ARSENAULT', Decimal('134.73'))
# ('CARL', 'ARTIS', Decimal('106.77'))
# ('DARRYL', 'ASHCRAFT', Decimal('76.77'))
# ('TYRONE', 'ASHER', Decimal('112.76'))
# ('ALMA', 'AUSTIN', Decimal('151.65'))
# ('MILDRED', 'BAILEY', Decimal('98.75'))
# ('PAMELA', 'BAKER', Decimal('95.77'))
# ('MARTIN', 'BALES', Decimal('103.73'))
# ('EVERETT', 'BANDA', Decimal('110.72'))
# ('JESSIE', 'BANKS', Decimal('91.74'))
# ('CLAYTON', 'BARBEE', Decimal('96.74'))
# ('ANGEL', 'BARCLAY', Decimal('115.68'))
# ('NICHOLAS', 'BARFIELD', Decimal('145.68'))
# ('VICTOR', 'BARKLEY', Decimal('91.76'))
# ('RACHEL', 'BARNES', Decimal('84.78'))
# ('CAROLE', 'BARNETT', Decimal('108.70'))
# ('TRACEY', 'BARRETT', Decimal('118.73'))
# ('DAISY', 'BATES', Decimal('162.62'))
# ('EDWARD', 'BAUGH', Decimal('114.72'))
# ('ROBERT', 'BAUGHMAN', Decimal('92.79'))
# ('JEAN', 'BELL', Decimal('115.73'))
# ('CHESTER', 'BENNER', Decimal('99.76'))
# ('JANE', 'BENNETT', Decimal('100.72'))
# ('REGINA', 'BERRY', Decimal('135.66'))
# ('CHARLIE', 'BESS', Decimal('120.74'))
# ('MIGUEL', 'BETANCOURT', Decimal('135.71'))
# ('HENRY', 'BILLINGSLEY', Decimal('73.82'))
# ('AGNES', 'BISHOP', Decimal('98.77'))
# ('VALERIE', 'BLACK', Decimal('121.74'))
# ('DEREK', 'BLAKELY', Decimal('97.72'))
# ('MATHEW', 'BOLIN', Decimal('90.78'))
# ('DON', 'BONE', Decimal('133.75'))
# ('LEON', 'BOSTIC', Decimal('109.75'))
# ('BOBBY', 'BOUDREAU', Decimal('106.65'))
# ('DERRICK', 'BOURQUE', Decimal('95.78'))
# ('CLIFFORD', 'BOWENS', Decimal('113.71'))
# ('CAROLINE', 'BOWMAN', Decimal('50.85'))
# ('BYRON', 'BOX', Decimal('120.71'))
# ('EMMA', 'BOYD', Decimal('94.77'))
# ('ANA', 'BRADLEY', Decimal('174.66'))
# ('TED', 'BREAUX', Decimal('117.71'))
# ('VICKIE', 'BREWER', Decimal('120.69'))
# ('RUSSELL', 'BRINSON', Decimal('136.64'))
# ('BEVERLY', 'BROOKS', Decimal('97.76'))
# ('CHRIS', 'BROTHERS', Decimal('84.78'))
# ('ELIZABETH', 'BROWN', Decimal('144.62'))
# ('GUY', 'BROWNLEE', Decimal('159.68'))
# ('PAULA', 'BRYANT', Decimal('77.82'))
# ('CLINTON', 'BUFORD', Decimal('103.75'))
# ('WESLEY', 'BULL', Decimal('177.60'))
# ('TIMOTHY', 'BUNN', Decimal('91.78'))
# ('EDWIN', 'BURK', Decimal('116.77'))
# ('LYDIA', 'BURKE', Decimal('82.76'))
# ('SIDNEY', 'BURLESON', Decimal('108.75'))
# ('APRIL', 'BURNS', Decimal('94.74'))
# ('COLLEEN', 'BURTON', Decimal('87.76'))
# ('LEROY', 'BUSTAMANTE', Decimal('118.68'))
# ('LOIS', 'BUTLER', Decimal('113.65'))
# ('ALLEN', 'BUTTERFIELD', Decimal('85.79'))
# ('DEANNA', 'BYRD', Decimal('107.74'))
# ('DANIEL', 'CABRAL', Decimal('97.80'))
# ('KAY', 'CALDWELL', Decimal('98.80'))
# ('CATHERINE', 'CAMPBELL', Decimal('142.66'))
# ('CHAD', 'CARBONE', Decimal('89.75'))
# ('TERRY', 'CARLSON', Decimal('127.71'))
# ('LORETTA', 'CARPENTER', Decimal('93.78'))
# ('EILEEN', 'CARR', Decimal('80.82'))
# ('TONY', 'CARRANZA', Decimal('74.78'))
# ('JUNE', 'CARROLL', Decimal('173.63'))
# ('AMANDA', 'CARTER', Decimal('110.73'))
# ('TIM', 'CARY', Decimal('175.61'))
# ('ALFRED', 'CASILLAS', Decimal('120.74'))
# ('GERTRUDE', 'CASTILLO', Decimal('137.66'))
# ('JENNY', 'CASTRO', Decimal('103.73'))
# ('PHILIP', 'CAUSEY', Decimal('121.69'))
# ('KRISTINA', 'CHAMBERS', Decimal('109.72'))
# ('VERNON', 'CHAPA', Decimal('88.82'))
# ('TONYA', 'CHAPMAN', Decimal('161.68'))
# ('KRISTEN', 'CHAVEZ', Decimal('87.82'))
# ('MARIO', 'CHEATHAM', Decimal('112.72'))
# ('PEDRO', 'CHESTNUT', Decimal('103.76'))
# ('JOHNNIE', 'CHISHOLM', Decimal('121.76'))
# ('RAMON', 'CHOATE', Decimal('140.69'))
# ('NELSON', 'CHRISTENSON', Decimal('77.80'))
# ('FERNANDO', 'CHURCHILL', Decimal('117.75'))
# ('AUSTIN', 'CINTRON', Decimal('83.81'))
# ('MICHELLE', 'CLARK', Decimal('155.65'))
# ('ADRIAN', 'CLARY', Decimal('74.81'))
# ('BERNARD', 'COLBY', Decimal('88.78'))
# ('TRACY', 'COLE', Decimal('132.70'))
# ('KATHRYN', 'COLEMAN', Decimal('130.74'))
# ('TOMMY', 'COLLAZO', Decimal('186.62'))
# ('DIANE', 'COLLINS', Decimal('169.65'))
# ('GLORIA', 'COOK', Decimal('135.70'))
# ('JOAN', 'COOPER', Decimal('84.77'))
# ('ALLAN', 'CORNISH', Decimal('79.81'))
# ('BRETT', 'CORNWELL', Decimal('138.66'))
# ('CARLOS', 'COUGHLIN', Decimal('106.77'))
# ('JUDITH', 'COX', Decimal('100.67'))
# ('GARY', 'COY', Decimal('103.75'))
# ('BOBBIE', 'CRAIG', Decimal('80.76'))
# ('ESTHER', 'CRAWFORD', Decimal('95.72'))
# ('MAURICE', 'CRAWLEY', Decimal('138.71'))
# ('IVAN', 'CROMWELL', Decimal('99.74'))
# ('ALBERT', 'CROUSE', Decimal('99.77'))
# ('KIM', 'CRUZ', Decimal('82.79'))
# ('THEODORE', 'CULP', Decimal('116.69'))
# ('EUGENE', 'CULPEPPER', Decimal('71.81'))
# ('STACY', 'CUNNINGHAM', Decimal('98.77'))
# ('STEVEN', 'CURLEY', Decimal('132.71'))
# ('NORMAN', 'CURRIER', Decimal('80.74'))
# ('LEAH', 'CURTIS', Decimal('104.75'))
# ('DANIELLE', 'DANIELS', Decimal('105.75'))
# ('PATSY', 'DAVIDSON', Decimal('119.72'))
# ('JENNIFER', 'DAVIS', Decimal('93.72'))
# ('COURTNEY', 'DAY', Decimal('132.68'))
# ('MARCIA', 'DEAN', Decimal('175.58'))
# ('ALVIN', 'DELOACH', Decimal('139.71'))
# ('RON', 'DELUCA', Decimal('103.77'))
# ('WADE', 'DELVALLE', Decimal('83.78'))
# ('HERMAN', 'DEVORE', Decimal('115.71'))
# ('EMILY', 'DIAZ', Decimal('91.76'))
# ('AMBER', 'DIXON', Decimal('113.73'))
# ('MARSHA', 'DOUGLAS', Decimal('151.63'))
# ('SEAN', 'DOUGLASS', Decimal('91.77'))
# ('LLOYD', 'DOWD', Decimal('66.81'))
# ('FREDDIE', 'DUGGAN', Decimal('99.75'))
# ('SAMANTHA', 'DUNCAN', Decimal('71.77'))
# ('ERIN', 'DUNN', Decimal('106.73'))
# ('JEFF', 'EAST', Decimal('107.70'))
# ('BEN', 'EASTER', Decimal('122.74'))
# ('LEO', 'EBERT', Decimal('104.77'))
# ('JOYCE', 'EDWARDS', Decimal('130.72'))
# ('JIMMIE', 'EGGLESTON', Decimal('135.72'))
# ('MELVIN', 'ELLINGTON', Decimal('97.74'))
# ('KATIE', 'ELLIOTT', Decimal('109.75'))
# ('GRACE', 'ELLIS', Decimal('139.67'))
# ('JAVIER', 'ELROD', Decimal('135.68'))
# ('JARED', 'ELY', Decimal('87.81'))
# ('KURT', 'EMMONS', Decimal('99.77'))
# ('TRAVIS', 'ESTEP', Decimal('110.75'))
# ('ANN', 'EVANS', Decimal('76.83'))
# ('JOHN', 'FARNSWORTH', Decimal('137.69'))
# ('ALEXANDER', 'FENNELL', Decimal('151.64'))
# ('BERTHA', 'FERGUSON', Decimal('101.75'))
# ('MELINDA', 'FERNANDEZ', Decimal('80.83'))
# ('VICKI', 'FIELDS', Decimal('108.75'))
# ('CINDY', 'FISHER', Decimal('113.71'))
# ('MYRTLE', 'FLEMING', Decimal('110.76'))
# ('MAE', 'FLETCHER', Decimal('158.69'))
# ('JULIA', 'FLORES', Decimal('134.68'))
# ('CRYSTAL', 'FORD', Decimal('137.67'))
# ('MICHEAL', 'FORMAN', Decimal('102.74'))
# ('ENRIQUE', 'FORSYTHE', Decimal('96.72'))
# ('RAUL', 'FORTIER', Decimal('100.80'))
# ('HOWARD', 'FORTNER', Decimal('93.74'))
# ('PHYLLIS', 'FOSTER', Decimal('91.77'))
# ('JACK', 'FOUST', Decimal('89.76'))
# ('JO', 'FOWLER', Decimal('73.80'))
# ('HOLLY', 'FOX', Decimal('114.69'))
# ('JUAN', 'FRALEY', Decimal('73.77'))
# ('JOEL', 'FRANCISCO', Decimal('95.77'))
# ('BETH', 'FRANKLIN', Decimal('103.75'))
# ('GLENDA', 'FRAZIER', Decimal('140.68'))
# ('SHANNON', 'FREEMAN', Decimal('100.76'))
# ('CLAUDIA', 'FULLER', Decimal('111.74'))
# ('GERALD', 'FULTZ', Decimal('121.70'))
# ('FELIX', 'GAFFNEY', Decimal('73.76'))
# ('RANDY', 'GAITHER', Decimal('110.72'))
# ('CLARENCE', 'GAMEZ', Decimal('104.70'))
# ('FLOYD', 'GANDY', Decimal('69.83'))
# ('JAMES', 'GANNON', Decimal('131.70'))
# ('CAROL', 'GARCIA', Decimal('91.78'))
# ('DAVE', 'GARDINER', Decimal('134.68'))
# ('JOANN', 'GARDNER', Decimal('66.84'))
# ('NELLIE', 'GARRETT', Decimal('94.79'))
# ('PEARL', 'GARZA', Decimal('76.78'))
# ('BILL', 'GAVIN', Decimal('114.72'))
# ('RUBEN', 'GEARY', Decimal('89.79'))
# ('JOY', 'GEORGE', Decimal('124.67'))
# ('VICTORIA', 'GIBSON', Decimal('111.73'))
# ('TANYA', 'GILBERT', Decimal('144.67'))
# ('DUSTIN', 'GILLETTE', Decimal('100.74'))
# ('JOE', 'GILLILAND', Decimal('138.71'))
# ('DENNIS', 'GILMAN', Decimal('114.72'))
# ('JOSEPHINE', 'GOMEZ', Decimal('109.74'))
# ('NORMA', 'GONZALES', Decimal('79.79'))
# ('MARTHA', 'GONZALEZ', Decimal('127.66'))
# ('ADAM', 'GOOCH', Decimal('101.78'))
# ('KENNETH', 'GOODEN', Decimal('84.83'))
# ('LESLIE', 'GORDON', Decimal('89.78'))
# ('DOUGLAS', 'GRAF', Decimal('114.75'))
# ('RITA', 'GRAHAM', Decimal('92.76'))
# ('MICHELE', 'GRANT', Decimal('130.70'))
# ('BRANDY', 'GRAVES', Decimal('122.72'))
# ('JUDY', 'GRAY', Decimal('96.75'))
# ('CHRISTOPHER', 'GRECO', Decimal('147.69'))
# ('VIRGINIA', 'GREEN', Decimal('129.68'))
# ('JEANETTE', 'GREENE', Decimal('74.80'))
# ('SONIA', 'GREGORY', Decimal('126.72'))
# ('ALEX', 'GRESHAM', Decimal('151.67'))
# ('ROSS', 'GREY', Decimal('99.73'))
# ('LILLIAN', 'GRIFFIN', Decimal('106.75'))
# ('THOMAS', 'GRIGSBY', Decimal('105.75'))
# ('TERRY', 'GRISSOM', Decimal('72.80'))
# ('ARMANDO', 'GRUBER', Decimal('83.79'))
# ('HARVEY', 'GUAJARDO', Decimal('93.78'))
# ('ERIK', 'GUILLEN', Decimal('118.71'))
# ('TERRENCE', 'GUNDERSON', Decimal('117.70'))
# ('CARLA', 'GUTIERREZ', Decimal('103.74'))
# ('RAMONA', 'HALE', Decimal('129.70'))
# ('JESSICA', 'HALL', Decimal('152.66'))
# ('GLADYS', 'HAMILTON', Decimal('146.69'))
# ('SETH', 'HANNON', Decimal('112.75'))
# ('DELORES', 'HANSEN', Decimal('91.79'))
# ('VIOLA', 'HANSON', Decimal('129.68'))
# ('GABRIEL', 'HARDER', Decimal('111.74'))
# ('BRYAN', 'HARDISON', Decimal('124.72'))
# ('BRENT', 'HARKINS', Decimal('112.77'))
# ('ROBERTA', 'HARPER', Decimal('84.77'))
# ('HELEN', 'HARRIS', Decimal('134.68'))
# ('WENDY', 'HARRISON', Decimal('91.70'))
# ('DANA', 'HART', Decimal('133.71'))
# ('ARLENE', 'HARVEY', Decimal('120.74'))
# ('COREY', 'HAUSER', Decimal('101.78'))
# ('ARNOLD', 'HAVENS', Decimal('167.67'))
# ('JILL', 'HAWKINS', Decimal('68.79'))
# ('LEE', 'HAWKS', Decimal('119.73'))
# ('ROBIN', 'HAYES', Decimal('102.76'))
# ('SHAWN', 'HEATON', Decimal('152.67'))
# ('ANDREA', 'HENDERSON', Decimal('93.78'))
# ('ALBERTO', 'HENNING', Decimal('66.79'))
# ('PAULINE', 'HENRY', Decimal('98.73'))
# ('ANGELA', 'HERNANDEZ', Decimal('140.64'))
# ('NORA', 'HERRERA', Decimal('118.72'))
# ('TRACY', 'HERRMANN', Decimal('129.72'))
# ('CLAUDE', 'HERZOG', Decimal('111.75'))
# ('EDUARDO', 'HIATT', Decimal('130.73'))
# ('MONICA', 'HICKS', Decimal('128.70'))
# ('MARCUS', 'HIDALGO', Decimal('115.70'))
# ('ANNA', 'HILL', Decimal('91.79'))
# ('ZACHARY', 'HITE', Decimal('146.69'))
# ('MATTIE', 'HOFFMAN', Decimal('64.78'))
# ('MABEL', 'HOLLAND', Decimal('112.70'))
# ('PHILLIP', 'HOLM', Decimal('101.74'))
# ('LUCILLE', 'HOLMES', Decimal('108.72'))
# ('TONI', 'HOLT', Decimal('95.77'))
# ('HILDA', 'HOPKINS', Decimal('122.71'))
# ('BILLIE', 'HORTON', Decimal('88.74'))
# ('RAY', 'HOULE', Decimal('79.78'))
# ('ROSE', 'HOWARD', Decimal('103.78'))
# ('WILLIE', 'HOWELL', Decimal('101.74'))
# ('MILTON', 'HOWLAND', Decimal('127.75'))
# ('LAUREN', 'HUDSON', Decimal('71.80'))
# ('BRANDON', 'HUEY', Decimal('152.63'))
# ('BONNIE', 'HUGHES', Decimal('87.79'))
# ('ELEANOR', 'HUNT', Decimal('216.54'))
# ('CHARLOTTE', 'HUNTER', Decimal('93.76'))
# ('JEREMY', 'HURTADO', Decimal('103.72'))
# ('CURTIS', 'IRBY', Decimal('167.62'))
# ('FREDERICK', 'ISBELL', Decimal('105.79'))
# ('DANNY', 'ISOM', Decimal('91.79'))
# ('KAREN', 'JACKSON', Decimal('131.73'))
# ('GEORGIA', 'JACOBS', Decimal('110.74'))
# ('KATHY', 'JAMES', Decimal('129.70'))
# ('LOUISE', 'JENKINS', Decimal('101.75'))
# ('NAOMI', 'JENNINGS', Decimal('152.65'))
# ('LENA', 'JENSEN', Decimal('170.67'))
# ('OLGA', 'JIMENEZ', Decimal('144.68'))
# ('PATRICIA', 'JOHNSON', Decimal('128.73'))
# ('KRISTIN', 'JOHNSTON', Decimal('116.69'))
# ('BARBARA', 'JONES', Decimal('81.78'))
# ('TIFFANY', 'JORDAN', Decimal('59.86'))
# ('JERRY', 'JORDON', Decimal('143.71'))
# ('JOSEPH', 'JOY', Decimal('134.70'))
# ('CHRISTIAN', 'JUNG', Decimal('88.76'))
# ('ALAN', 'KAHN', Decimal('124.74'))
# ('ELSIE', 'KELLEY', Decimal('141.63'))
# ('DENISE', 'KELLY', Decimal('103.73'))
# ('RHONDA', 'KENNEDY', Decimal('194.61'))
# ('JEROME', 'KENYON', Decimal('73.84'))
# ('LILLIE', 'KIM', Decimal('89.77'))
# ('REGINALD', 'KINDER', Decimal('115.72'))
# ('MELISSA', 'KING', Decimal('123.66'))
# ('GAIL', 'KNIGHT', Decimal('109.75'))
# ('KELLY', 'KNOTT', Decimal('107.74'))
# ('CHARLES', 'KOWALSKI', Decimal('138.68'))
# ('LESTER', 'KRAUS', Decimal('65.84'))
# ('HERBERT', 'KRUGER', Decimal('78.80'))
# ('MISTY', 'LAMBERT', Decimal('118.73'))
# ('JACOB', 'LANCE', Decimal('79.79'))
# ('RENEE', 'LANE', Decimal('97.74'))
# ('HEIDI', 'LARSON', Decimal('122.66'))
# ('DARYL', 'LARUE', Decimal('111.73'))
# ('LAURIE', 'LAWRENCE', Decimal('99.77'))
# ('JEANNE', 'LAWSON', Decimal('136.73'))
# ('LAWRENCE', 'LAWTON', Decimal('100.69'))
# ('KIMBERLY', 'LEE', Decimal('95.75'))
# ('LOUIS', 'LEONE', Decimal('161.65'))
# ('SARAH', 'LEWIS', Decimal('119.70'))
# ('GEORGE', 'LINTON', Decimal('131.67'))
# ('MAUREEN', 'LITTLE', Decimal('87.79'))
# ('DWIGHT', 'LOMBARDI', Decimal('74.83'))
# ('JACQUELINE', 'LONG', Decimal('148.67'))
# ('AMY', 'LOPEZ', Decimal('127.71'))
# ('BARRY', 'LOVELACE', Decimal('134.67'))
# ('PRISCILLA', 'LOWE', Decimal('157.65'))
# ('VELMA', 'LUCAS', Decimal('117.73'))
# ('WILLARD', 'LUMPKIN', Decimal('96.78'))
# ('LEWIS', 'LYMAN', Decimal('86.81'))
# ('JACKIE', 'LYNCH', Decimal('93.75'))
# ('STEVE', 'MACKENZIE', Decimal('158.66'))
# ('RALPH', 'MADRIGAL', Decimal('150.66'))
# ('MATTHEW', 'MAHAN', Decimal('114.69'))
# ('DONALD', 'MAHON', Decimal('89.77'))
# ('CLIFTON', 'MALCOLM', Decimal('118.72'))
# ('JOSHUA', 'MARK', Decimal('119.70'))
# ('WILLIE', 'MARKHAM', Decimal('101.75'))
# ('SAMUEL', 'MARLOW', Decimal('80.79'))
# ('SHERRY', 'MARSHALL', Decimal('153.66'))
# ('CALVIN', 'MARTEL', Decimal('111.77'))
# ('SANDRA', 'MARTIN', Decimal('120.71'))
# ('RUTH', 'MARTINEZ', Decimal('125.76'))
# ('HAROLD', 'MARTINO', Decimal('130.68'))
# ('JUANITA', 'MASON', Decimal('110.70'))
# ('ERICA', 'MATTHEWS', Decimal('95.78'))
# ('RICK', 'MATTOX', Decimal('124.73'))
# ('GREGORY', 'MAULDIN', Decimal('78.77'))
# ('GWENDOLYN', 'MAY', Decimal('98.75'))
# ('ALFREDO', 'MCADAMS', Decimal('85.80'))
# ('RENE', 'MCALISTER', Decimal('113.74'))
# ('MORRIS', 'MCCARTER', Decimal('139.66'))
# ('JESUS', 'MCCARTNEY', Decimal('114.76'))
# ('VERA', 'MCCOY', Decimal('67.82'))
# ('RICHARD', 'MCCRARY', Decimal('109.75'))
# ('BRAD', 'MCCURDY', Decimal('105.75'))
# ('EDITH', 'MCDONALD', Decimal('71.81'))
# ('SAM', 'MCDUFFIE', Decimal('117.76'))
# ('MIRIAM', 'MCKINNEY', Decimal('135.74'))
# ('RAYMOND', 'MCWHORTER', Decimal('135.70'))
# ('RICARDO', 'MEADOR', Decimal('99.79'))
# ('DORA', 'MEDINA', Decimal('107.77'))
# ('CORY', 'MEEHAN', Decimal('81.76'))
# ('ANTONIO', 'MEEK', Decimal('78.84'))
# ('CASEY', 'MENA', Decimal('141.66'))
# ('PETER', 'MENARD', Decimal('106.77'))
# ('MARIAN', 'MENDOZA', Decimal('107.77'))
# ('NATALIE', 'MEYER', Decimal('95.77'))
# ('JESSIE', 'MILAM', Decimal('141.67'))
# ('BECKY', 'MILES', Decimal('115.71'))
# ('SHANE', 'MILLARD', Decimal('95.78'))
# ('MARIA', 'MILLER', Decimal('151.67'))
# ('ALICIA', 'MILLS', Decimal('83.79'))
# ('TOM', 'MILNER', Decimal('107.68'))
# ('STEPHANIE', 'MITCHELL', Decimal('118.75'))
# ('RODNEY', 'MOELLER', Decimal('104.77'))
# ('STACEY', 'MONTGOMERY', Decimal('151.66'))
# ('MARGARET', 'MOORE', Decimal('89.77'))
# ('ANITA', 'MORALES', Decimal('62.85'))
# ('STELLA', 'MORENO', Decimal('104.78'))
# ('EVELYN', 'MORGAN', Decimal('114.72'))
# ('CRAIG', 'MORRELL', Decimal('124.70'))
# ('HEATHER', 'MORRIS', Decimal('115.70'))
# ('BESSIE', 'MORRISON', Decimal('132.72'))
# ('JASON', 'MORRISSEY', Decimal('128.72'))
# ('BRADLEY', 'MOTLEY', Decimal('126.73'))
# ('CHERYL', 'MURPHY', Decimal('133.73'))
# ('THELMA', 'MURRAY', Decimal('126.68'))
# ('MANUEL', 'MURRELL', Decimal('116.70'))
# ('PEGGY', 'MYERS', Decimal('96.76'))
# ('PENNY', 'NEAL', Decimal('68.82'))
# ('DEBRA', 'NELSON', Decimal('141.71'))
# ('JAIME', 'NETTLES', Decimal('126.71'))
# ('RANDALL', 'NEUMANN', Decimal('99.77'))
# ('PATRICK', 'NEWSOM', Decimal('119.69'))
# ('JUSTIN', 'NGO', Decimal('129.64'))
# ('TAMARA', 'NGUYEN', Decimal('93.75'))
# ('SUZANNE', 'NICHOLS', Decimal('94.76'))
# ('ELMER', 'NOE', Decimal('98.74'))
# ('JULIO', 'NOLAND', Decimal('89.79'))
# ('CODY', 'NOLEN', Decimal('98.78'))
# ('LEONA', 'OBRIEN', Decimal('50.86'))
# ('MARION', 'OCAMPO', Decimal('115.71'))
# ('ISAAC', 'OGLESBY', Decimal('126.71'))
# ('JORGE', 'OLIVARES', Decimal('134.66'))
# ('ELLA', 'OLIVER', Decimal('137.69'))
# ('ANNETTE', 'OLSON', Decimal('98.76'))
# ('DWAYNE', 'OLVERA', Decimal('101.78'))
# ('SYLVIA', 'ORTIZ', Decimal('143.68'))
# ('MARC', 'OUTLAW', Decimal('123.70'))
# ('CARMEN', 'OWENS', Decimal('97.74'))
# ('DAN', 'PAINE', Decimal('109.78'))
# ('MEGAN', 'PALMER', Decimal('92.73'))
# ('FRANCES', 'PARKER', Decimal('108.78'))
# ('WANDA', 'PATTERSON', Decimal('145.70'))
# ('LYNN', 'PAYNE', Decimal('123.72'))
# ('IRMA', 'PEARSON', Decimal('70.82'))
# ('LANCE', 'PEMBERTON', Decimal('82.78'))
# ('ERIKA', 'PENA', Decimal('101.74'))
# ('CAROLYN', 'PEREZ', Decimal('117.70'))
# ('GERALDINE', 'PERKINS', Decimal('112.70'))
# ('SARA', 'PERRY', Decimal('141.67'))
# ('WALTER', 'PERRYMAN', Decimal('127.70'))
# ('SUE', 'PETERS', Decimal('154.60'))
# ('NICOLE', 'PETERSON', Decimal('94.78'))
# ('BOB', 'PFEIFFER', Decimal('91.76'))
# ('JANET', 'PHILLIPS', Decimal('127.73'))
# ('SALLY', 'PIERCE', Decimal('119.68'))
# ('JEFFERY', 'PINSON', Decimal('121.69'))
# ('MAX', 'PITT', Decimal('107.76'))
# ('HECTOR', 'POINDEXTER', Decimal('119.74'))
# ('CARRIE', 'PORTER', Decimal('124.66'))
# ('BILLY', 'POULIN', Decimal('149.65'))
# ('ANNE', 'POWELL', Decimal('87.77'))
# ('DARRELL', 'POWER', Decimal('91.75'))
# ('KEN', 'PREWITT', Decimal('110.71'))
# ('IRENE', 'PRICE', Decimal('77.77'))
# ('GLENN', 'PULLEN', Decimal('93.77'))
# ('ANDREW', 'PURDY', Decimal('109.73'))
# ('STEPHEN', 'QUALLS', Decimal('118.72'))
# ('TROY', 'QUIGLEY', Decimal('144.70'))
# ('ROGER', 'QUINTANILLA', Decimal('146.64'))
# ('VINCENT', 'RALSTON', Decimal('105.75'))
# ('CHRISTINA', 'RAMIREZ', Decimal('80.82'))
# ('EVA', 'RAMOS', Decimal('83.82'))
# ('ANDRE', 'RAPP', Decimal('126.72'))
# ('DALE', 'RATCLIFF', Decimal('112.73'))
# ('AUDREY', 'RAY', Decimal('119.71'))
# ('JIM', 'REA', Decimal('128.67'))
# ('DORIS', 'REED', Decimal('100.78'))
# ('CONSTANCE', 'REID', Decimal('95.75'))
# ('NEIL', 'RENNER', Decimal('152.68'))
# ('DEBBIE', 'REYES', Decimal('130.68'))
# ('ROSA', 'REYNOLDS', Decimal('133.70'))
# ('EDGAR', 'RHOADS', Decimal('95.75'))
# ('SHERRI', 'RHODES', Decimal('128.67'))
# ('JAMIE', 'RICE', Decimal('139.71'))
# ('WILMA', 'RICHARDS', Decimal('91.80'))
# ('ASHLEY', 'RICHARDSON', Decimal('112.75'))
# ('RONNIE', 'RICKETTS', Decimal('100.75'))
# ('KEITH', 'RICO', Decimal('89.74'))
# ('BRITTANY', 'RILEY', Decimal('159.72'))
# ('MARK', 'RINEHART', Decimal('104.74'))
# ('KATHERINE', 'RIVERA', Decimal('58.86'))
# ('JAY', 'ROBB', Decimal('89.74'))
# ('ERIC', 'ROBERT', Decimal('122.73'))
# ('CHRISTINE', 'ROBERTS', Decimal('99.76'))
# ('JOANNE', 'ROBERTSON', Decimal('127.66'))
# ('GREG', 'ROBINS', Decimal('141.70'))
# ('SHARON', 'ROBINSON', Decimal('115.70'))
# ('LAURA', 'RODRIGUEZ', Decimal('113.78'))
# ('VIOLET', 'RODRIQUEZ', Decimal('142.70'))
# ('TERESA', 'ROGERS', Decimal('128.71'))
# ('MINNIE', 'ROMERO', Decimal('142.66'))
# ('DARLENE', 'ROSE', Decimal('113.69'))
# ('MARILYN', 'ROSS', Decimal('137.70'))
# ('TERRANCE', 'ROUSH', Decimal('111.71'))
# ('DAVID', 'ROYAL', Decimal('115.74'))
# ('VIVIAN', 'RUIZ', Decimal('90.77'))
# ('NATHAN', 'RUNYON', Decimal('122.68'))
# ('ANNIE', 'RUSSELL', Decimal('58.82'))
# ('TARA', 'RYAN', Decimal('88.80'))
# ('RYAN', 'SALISBURY', Decimal('142.70'))
# ('GENE', 'SANBORN', Decimal('97.73'))
# ('JULIE', 'SANCHEZ', Decimal('107.71'))
# ('TAMMY', 'SANDERS', Decimal('155.59'))
# ('WILLIAM', 'SATTERFIELD', Decimal('100.74'))
# ('DEAN', 'SAUER', Decimal('109.73'))
# ('JONATHAN', 'SCARBOROUGH', Decimal('72.82'))
# ('JESSE', 'SCHILLING', Decimal('101.74'))
# ('ROSEMARY', 'SCHMIDT', Decimal('147.65'))
# ('LEONARD', 'SCHOFIELD', Decimal('109.68'))
# ('JIMMY', 'SCHRADER', Decimal('105.71'))
# ('KEVIN', 'SCHULER', Decimal('116.78'))
# ('ANTHONY', 'SCHWAB', Decimal('71.80'))
# ('BRUCE', 'SCHWARZ', Decimal('103.77'))
# ('REBECCA', 'SCOTT', Decimal('89.76'))
# ('STANLEY', 'SCROGGINS', Decimal('139.70'))
# ('KARL', 'SEAL', Decimal('221.55'))
# ('AARON', 'SELBY', Decimal('110.76'))
# ('LESLIE', 'SEWARD', Decimal('152.65'))
# ('EARL', 'SHANKS', Decimal('111.73'))
# ('CLARA', 'SHAW', Decimal('195.58'))
# ('RICKY', 'SHELBY', Decimal('91.75'))
# ('SCOTT', 'SHELLEY', Decimal('94.75'))
# ('DIANNE', 'SHELTON', Decimal('135.69'))
# ('WARREN', 'SHERROD', Decimal('159.67'))
# ('FRANCIS', 'SIKES', Decimal('104.74'))
# ('MAXINE', 'SILVA', Decimal('116.68'))
# ('MICHAEL', 'SILVERMAN', Decimal('127.71'))
# ('TINA', 'SIMMONS', Decimal('133.72'))
# ('ARTHUR', 'SIMPKINS', Decimal('155.68'))
# ('ELLEN', 'SIMPSON', Decimal('117.72'))
# ('VANESSA', 'SIMS', Decimal('86.81'))
# ('FRANCISCO', 'SKIDMORE', Decimal('98.78'))
# ('GILBERT', 'SLEDGE', Decimal('129.72'))
# ('WALLACE', 'SLONE', Decimal('109.75'))
# ('MARY', 'SMITH', Decimal('118.68'))
# ('MARION', 'SNYDER', Decimal('194.61'))
# ('NINA', 'SOTO', Decimal('123.71'))
# ('ROLAND', 'SOUTH', Decimal('80.77'))
# ('JEFFREY', 'SPEAR', Decimal('90.77'))
# ('CATHY', 'SPENCER', Decimal('122.71'))
# ('KYLE', 'SPURLOCK', Decimal('110.70'))
# ('SERGIO', 'STANFIELD', Decimal('108.74'))
# ('ALLISON', 'STANLEY', Decimal('92.73'))
# ('KIRK', 'STCLAIR', Decimal('64.81'))
# ('LORRAINE', 'STEPHENS', Decimal('86.79'))
# ('ERNEST', 'STEPP', Decimal('89.75'))
# ('ELAINE', 'STEVENS', Decimal('107.76'))
# ('ALICE', 'STEWART', Decimal('138.67'))
# ('IAN', 'STILL', Decimal('96.73'))
# ('VERONICA', 'STONE', Decimal('126.68'))
# ('DAWN', 'SULLIVAN', Decimal('120.74'))
# ('FELICIA', 'SUTTON', Decimal('86.72'))
# ('PERRY', 'SWAFFORD', Decimal('117.76'))
# ('GLEN', 'TALBERT', Decimal('113.74'))
# ('TODD', 'TAN', Decimal('117.71'))
# ('DOROTHY', 'TAYLOR', Decimal('99.75'))
# ('SALVADOR', 'TEEL', Decimal('129.70'))
# ('JENNIE', 'TERRY', Decimal('133.71'))
# ('NANCY', 'THOMAS', Decimal('103.72'))
# ('DONNA', 'THOMPSON', Decimal('98.79'))
# ('MARSHALL', 'THORN', Decimal('117.77'))
# ('LARRY', 'THRASHER', Decimal('112.74'))
# ('LONNIE', 'TIRADO', Decimal('94.82'))
# ('CLYDE', 'TOBIAS', Decimal('115.71'))
# ('EDDIE', 'TOMLIN', Decimal('128.73'))
# ('KELLY', 'TORRES', Decimal('99.78'))
# ('PAUL', 'TROUT', Decimal('120.77'))
# ('FRANKLIN', 'TROUTMAN', Decimal('74.78'))
# ('WAYNE', 'TRUONG', Decimal('70.81'))
# ('DUANE', 'TUBBS', Decimal('148.69'))
# ('MARJORIE', 'TUCKER', Decimal('127.68'))
# ('MARIE', 'TURNER', Decimal('114.74'))
# ('JOHNNY', 'TURPIN', Decimal('57.81'))
# ('ANDY', 'VANHORN', Decimal('113.75'))
# ('CHRISTY', 'VARGAS', Decimal('122.69'))
# ('BENJAMIN', 'VARNEY', Decimal('95.77'))
# ('TERRI', 'VASQUEZ', Decimal('126.73'))
# ('JULIAN', 'VEST', Decimal('109.72'))
# ('CECIL', 'VINES', Decimal('115.74'))
# ('ROBERTO', 'VU', Decimal('139.70'))
# ('MARGIE', 'WADE', Decimal('159.64'))
# ('FRANK', 'WAGGONER', Decimal('127.68'))
# ('DOLORES', 'WAGNER', Decimal('114.74'))
# ('HUGH', 'WALDROP', Decimal('90.79'))
# ('DEBORAH', 'WALKER', Decimal('115.71'))
# ('CONNIE', 'WALLACE', Decimal('100.77'))
# ('CASSANDRA', 'WALTERS', Decimal('129.70'))
# ('JANICE', 'WARD', Decimal('144.66'))
# ('HAZEL', 'WARREN', Decimal('110.66'))
# ('RUBY', 'WASHINGTON', Decimal('110.72'))
# ('YVONNE', 'WATKINS', Decimal('92.79'))
# ('THERESA', 'WATSON', Decimal('99.70'))
# ('SHELLY', 'WATTS', Decimal('113.74'))
# ('JAMIE', 'WAUGH', Decimal('118.75'))
# ('MIKE', 'WAY', Decimal('166.65'))
# ('YOLANDA', 'WEAVER', Decimal('110.73'))
# ('ETHEL', 'WEBB', Decimal('135.68'))
# ('RONALD', 'WEINER', Decimal('132.70'))
# ('MARLENE', 'WELCH', Decimal('117.74'))
# ('SHEILA', 'WELLS', Decimal('73.82'))
# ('EDNA', 'WEST', Decimal('107.74'))
# ('MITCHELL', 'WESTMORELAND', Decimal('134.68'))
# ('FRED', 'WHEAT', Decimal('88.75'))
# ('LUCY', 'WHEELER', Decimal('91.74'))
# ('BETTY', 'WHITE', Decimal('117.72'))
# ('ROY', 'WHITING', Decimal('143.71'))
# ('JON', 'WILES', Decimal('87.76'))
# ('LINDA', 'WILLIAMS', Decimal('135.74'))
# ('GINA', 'WILLIAMSON', Decimal('111.72'))
# ('BERNICE', 'WILLIS', Decimal('145.67'))
# ('SUSAN', 'WILSON', Decimal('92.76'))
# ('DARREN', 'WINDHAM', Decimal('108.76'))
# ('VIRGIL', 'WOFFORD', Decimal('107.73'))
# ('LORI', 'WOOD', Decimal('141.69'))
# ('FLORENCE', 'WOODS', Decimal('126.70'))
# ('TYLER', 'WREN', Decimal('88.79'))
# ('BRENDA', 'WRIGHT', Decimal('104.74'))
# ('BRIAN', 'WYMAN', Decimal('52.88'))
# ('LUIS', 'YANEZ', Decimal('79.80'))
# ('MARVIN', 'YEE', Decimal('75.79'))
# ('CYNTHIA', 'YOUNG', Decimal('111.68'))
